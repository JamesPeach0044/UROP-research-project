# %% [markdown]
# # Finetune Llama-3 with LLaMA Factory
#
# Please use a **free** Tesla T4 Colab GPU to run this!
#
# Project homepage: https://github.com/hiyouga/LLaMA-Factory

# %% [markdown]
# ## Install Dependencies

# %%
# %cd /content/
# %rm -rf LLaMA-Factory
# !git clone --depth 1 https://github.com/hiyouga/LLaMA-Factory.git
# %cd LLaMA-Factory
# %ls
# !pip install -e .[torch,bitsandbytes]
# Out:
# [Errno 2] No such file or directory: '/content/'
# /app/llama-factory
# Cloning into 'LLaMA-Factory'...
# remote: Enumerating objects: 672, done.
# remote: Counting objects: 100% (672/672), done.
# remote: Compressing objects: 100% (510/510), done.
# remote: Total 672 (delta 153), reused 430 (delta 100), pack-reused 0 (from 0)
# Receiving objects: 100% (672/672), 5.36 MiB | 3.39 MiB/s, done.
# Resolving deltas: 100% (153/153), done.
# /app/llama-factory/LLaMA-Factory
# CITATION.cff  MANIFEST.in  README_zh.md  docker/    pyproject.toml  src/
# CLAUDE.md@    Makefile     assets/       docs/      requirements/   tests/
# LICENSE       README.md    data/         examples/  scripts/        tests_v1/
# Obtaining file:///app/llama-factory/LLaMA-Factory
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate<=1.11.0,>=1.3.0 in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (1.11.0)
# Requirement already satisfied: av<=16.0.0,>=10.0.0 in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (16.0.0)
# Requirement already satisfied: datasets<=4.0.0,>=2.16.0 in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (4.0.0)
# Requirement already satisfied: einops in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (0.8.1)
# Requirement already satisfied: fastapi in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (0.136.3)
# Requirement already satisfied: fire in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (0.7.1)
# Requirement already satisfied: gradio<=5.50.0,>=4.38.0 in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (5.50.0)
# Requirement already satisfied: hf-transfer in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (0.1.9)
# Requirement already satisfied: matplotlib>=3.7.0 in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (3.10.9)
# Requirement already satisfied: modelscope in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (1.37.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (2.2.2)
# Requirement already satisfied: omegaconf in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (2.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (26.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (2.3.3)
# Requirement already satisfied: peft<=0.18.1,>=0.18.0 in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (0.18.1)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (7.35.0)
# Requirement already satisfied: pydantic in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (2.12.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (6.0.2)
# Requirement already satisfied: safetensors in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (0.8.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (1.17.1)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (0.2.1)
# Requirement already satisfied: sse-starlette in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (3.4.4)
# Requirement already satisfied: tiktoken in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (0.13.0)
# Requirement already satisfied: torch>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (2.6.0+cu124)
# Requirement already satisfied: torchaudio>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (2.6.0+cu124)
# Requirement already satisfied: torchdata<=0.11.0,>=0.10.0 in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (0.11.0)
# Requirement already satisfied: torchvision>=0.19.0 in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (0.21.0+cu124)
# Requirement already satisfied: transformers!=4.52.0,!=4.57.0,<=5.6.0,>=4.55.0 in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (5.6.0)
# Requirement already satisfied: trl<=0.24.0,>=0.18.0 in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (0.24.0)
# Requirement already satisfied: tyro<0.9.0 in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (0.8.14)
# Requirement already satisfied: uvicorn in /opt/conda/lib/python3.11/site-packages (from llamafactory==0.9.6.dev0) (0.49.0)
# WARNING: llamafactory 0.9.6.dev0 does not provide the extra 'bitsandbytes'
# WARNING: llamafactory 0.9.6.dev0 does not provide the extra 'torch'
# Requirement already satisfied: psutil in /opt/conda/lib/python3.11/site-packages (from accelerate<=1.11.0,>=1.3.0->llamafactory==0.9.6.dev0) (6.1.1)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /opt/conda/lib/python3.11/site-packages (from accelerate<=1.11.0,>=1.3.0->llamafactory==0.9.6.dev0) (1.18.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (3.17.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.11/site-packages (from datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (24.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.11/site-packages (from datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.11/site-packages (from datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/conda/lib/python3.11/site-packages (from datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (4.67.1)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.11/site-packages (from datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.17 in /opt/conda/lib/python3.11/site-packages (from datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /opt/conda/lib/python3.11/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (2024.12.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.11/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (3.14.1)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /opt/conda/lib/python3.11/site-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /opt/conda/lib/python3.11/site-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (4.13.0)
# Requirement already satisfied: brotli>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (1.1.0)
# Requirement already satisfied: ffmpy in /opt/conda/lib/python3.11/site-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (1.0.0)
# Requirement already satisfied: gradio-client==1.14.0 in /opt/conda/lib/python3.11/site-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (1.14.0)
# Requirement already satisfied: groovy~=0.1 in /opt/conda/lib/python3.11/site-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /opt/conda/lib/python3.11/site-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /opt/conda/lib/python3.11/site-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (3.1.5)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /opt/conda/lib/python3.11/site-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (3.0.2)
# Requirement already satisfied: orjson~=3.0 in /opt/conda/lib/python3.11/site-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (3.11.9)
# Requirement already satisfied: pillow<12.0,>=8.0 in /opt/conda/lib/python3.11/site-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (11.0.0)
# Requirement already satisfied: pydub in /opt/conda/lib/python3.11/site-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /opt/conda/lib/python3.11/site-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (0.0.32)
# Requirement already satisfied: ruff>=0.9.3 in /opt/conda/lib/python3.11/site-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (0.15.16)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /opt/conda/lib/python3.11/site-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /opt/conda/lib/python3.11/site-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /opt/conda/lib/python3.11/site-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (0.52.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /opt/conda/lib/python3.11/site-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /opt/conda/lib/python3.11/site-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (0.25.1)
# Requirement already satisfied: typing-extensions~=4.0 in /opt/conda/lib/python3.11/site-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (4.15.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /opt/conda/lib/python3.11/site-packages (from gradio-client==1.14.0->gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.11/site-packages (from anyio<5.0,>=3.0->gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (3.10)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.11/site-packages (from fastapi->llamafactory==0.9.6.dev0) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/conda/lib/python3.11/site-packages (from fastapi->llamafactory==0.9.6.dev0) (0.0.4)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from httpx<1.0,>=0.24.1->gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx<1.0,>=0.24.1->gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (0.16.0)
# Requirement already satisfied: click>=8.4.0 in /opt/conda/lib/python3.11/site-packages (from huggingface_hub>=0.21.0->accelerate<=1.11.0,>=1.3.0->llamafactory==0.9.6.dev0) (8.4.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface_hub>=0.21.0->accelerate<=1.11.0,>=1.3.0->llamafactory==0.9.6.dev0) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->llamafactory==0.9.6.dev0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->llamafactory==0.9.6.dev0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas->llamafactory==0.9.6.dev0) (2026.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic->llamafactory==0.9.6.dev0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /opt/conda/lib/python3.11/site-packages (from pydantic->llamafactory==0.9.6.dev0) (2.41.4)
# Requirement already satisfied: urllib3>=1.25 in /opt/conda/lib/python3.11/site-packages (from torchdata<=0.11.0,>=0.10.0->llamafactory==0.9.6.dev0) (2.3.0)
# Requirement already satisfied: regex>=2025.10.22 in /opt/conda/lib/python3.11/site-packages (from transformers!=4.52.0,!=4.57.0,<=5.6.0,>=4.55.0->llamafactory==0.9.6.dev0) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/conda/lib/python3.11/site-packages (from transformers!=4.52.0,!=4.57.0,<=5.6.0,>=4.55.0->llamafactory==0.9.6.dev0) (0.22.2)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/conda/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /opt/conda/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (15.0.0)
# Requirement already satisfied: docstring-parser>=0.16 in /opt/conda/lib/python3.11/site-packages (from tyro<0.9.0->llamafactory==0.9.6.dev0) (0.18.0)
# Requirement already satisfied: shtab>=1.5.6 in /opt/conda/lib/python3.11/site-packages (from tyro<0.9.0->llamafactory==0.9.6.dev0) (1.8.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (1.24.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.7.0->llamafactory==0.9.6.dev0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.7.0->llamafactory==0.9.6.dev0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.7.0->llamafactory==0.9.6.dev0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.7.0->llamafactory==0.9.6.dev0) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.7.0->llamafactory==0.9.6.dev0) (3.3.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->llamafactory==0.9.6.dev0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (3.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0,>=0.12->gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (0.1.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (3.4.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy==1.13.1->torch>=2.4.0->llamafactory==0.9.6.dev0) (1.3.0)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.11/site-packages (from fire->llamafactory==0.9.6.dev0) (3.3.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from modelscope->llamafactory==0.9.6.dev0) (82.0.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /opt/conda/lib/python3.11/site-packages (from omegaconf->llamafactory==0.9.6.dev0) (4.9.3)
# Building wheels for collected packages: llamafactory
#   Building editable for llamafactory (pyproject.toml) ... done
#   Created wheel for llamafactory: filename=llamafactory-0.9.6.dev0-py3-none-any.whl size=26664 sha256=f32e983904b8f6541ef30c99482f4e5d4d5a168d6d573a97ac1b31ac7437d21b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tj8m20uf/wheels/af/75/a1/fb630312da4d2617ffa51747d17a5a7df3d032cf64c063a8f2
# Successfully built llamafactory
# Installing collected packages: llamafactory
#   Attempting uninstall: llamafactory
#     Found existing installation: llamafactory 0.9.6.dev0
#     Uninstalling llamafactory-0.9.6.dev0:
#       Successfully uninstalled llamafactory-0.9.6.dev0
# Successfully installed llamafactory-0.9.6.dev0

# %% [markdown]
# ### Check GPU environment

# %%
import torch
try:
  assert torch.cuda.is_available() is True
except AssertionError:
  print("Please set up a GPU before using LLaMA Factory: https://medium.com/mlearning-ai/training-yolov4-on-google-colab-316f8fff99c6")

# %% [markdown]
# ## Update Identity Dataset

# %%
import json

# %pwd
#%cd LLaMA-Factory


NAME = "Llama-3"
AUTHOR = "LLaMA-Factory"


with open("data/identity.json", "r", encoding="utf-8") as f:
  dataset = json.load(f)

for sample in dataset:
  sample["output"] = sample["output"].replace("{{"+ "name" + "}}", NAME).replace("{{"+ "author" + "}}", AUTHOR)

with open("data/identity.json", "w", encoding="utf-8") as f:
  json.dump(dataset, f, indent=2, ensure_ascii=False)

# %% [markdown]
# ## Fine-tune model via LLaMA Board

# %%
# %cd /content/LLaMA-Factory/
# !GRADIO_SHARE=1 llamafactory-cli webui

# %% [markdown]
# ## Fine-tune model via Command Line
#
# It takes ~30min for training.

# %%
import json

args = dict(
  stage="sft",                                               # do supervised fine-tuning
  do_train=True,
  model_name_or_path="unsloth/llama-3-8b-Instruct-bnb-4bit", # use bnb-4bit-quantized Llama-3-8B-Instruct model
  dataset="identity,alpaca_en_demo",                         # use alpaca and identity datasets
  template="llama3",                                         # use llama3 prompt template
  finetuning_type="lora",                                    # use LoRA adapters to save memory
  lora_target="all",                                         # attach LoRA adapters to all linear layers
  output_dir="llama3_lora",                                  # the path to save LoRA adapters
  per_device_train_batch_size=2,                             # the micro batch size
  gradient_accumulation_steps=4,                             # the gradient accumulation steps
  lr_scheduler_type="cosine",                                # use cosine learning rate scheduler
  logging_steps=5,                                           # log every 5 steps
  warmup_ratio=0.1,                                          # use warmup scheduler
  save_steps=1000,                                           # save checkpoint every 1000 steps
  learning_rate=5e-5,                                        # the learning rate
  num_train_epochs=3.0,                                      # the epochs of training
  max_samples=500,                                           # use 500 examples in each dataset
  max_grad_norm=1.0,                                         # clip gradient norm to 1.0
  loraplus_lr_ratio=16.0,                                    # use LoRA+ algorithm with lambda=16.0
  fp16=True,                                                 # use float16 mixed precision training
  report_to="none",                                          # disable wandb logging
)

json.dump(args, open("train_llama3.json", "w", encoding="utf-8"), indent=2)

#%cd LLaMA-Factory/
# %cd src

# !llamafactory-cli train train_llama3.json
# Out:
# /app/llama-factory/LLaMA-Factory/src
# Traceback (most recent call last):
#   File "/opt/conda/bin/llamafactory-cli", line 6, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/app/llama-factory/LLaMA-Factory/src/llamafactory/cli.py", line 24, in main
#     launcher.launch()
#   File "/app/llama-factory/LLaMA-Factory/src/llamafactory/launcher.py", line 157, in launch
#     run_exp()
#   File "/app/llama-factory/LLaMA-Factory/src/llamafactory/train/tuner.py", line 147, in run_exp
#     args = read_args(args)
#            ^^^^^^^^^^^^^^^
#   File "/app/llama-factory/LLaMA-Factory/src/llamafactory/hparams/parser.py", line 96, in read_args
#     dict_config = OmegaConf.create(json.load(Path(sys.argv[1]).absolute()))
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/json/__init__.py", line 293, in load
#     return loads(fp.read(),
#                  ^^^^^^^
# AttributeError: 'PosixPath' object has no attribute 'read'

# %%
# !pip show llamafactory

# %%
# !grep -n "json.load" /app/llama-factory/LLaMA-Factory/src/llamafactory/hparams/parser.py

# %% [markdown]
# ## Infer the fine-tuned model

# %%
from llamafactory.chat import ChatModel
from llamafactory.extras.misc import torch_gc

# %cd /content/LLaMA-Factory/

args = dict(
  model_name_or_path="unsloth/llama-3-8b-Instruct-bnb-4bit", # use bnb-4bit-quantized Llama-3-8B-Instruct model
  adapter_name_or_path="llama3_lora",                        # load the saved LoRA adapters
  template="llama3",                                         # same to the one in training
  finetuning_type="lora",                                    # same to the one in training
)
chat_model = ChatModel(args)

messages = []
print("Welcome to the CLI application, use `clear` to remove the history, use `exit` to exit the application.")
while True:
  query = input("\nUser: ")
  if query.strip() == "exit":
    break
  if query.strip() == "clear":
    messages = []
    torch_gc()
    print("History has been removed.")
    continue

  messages.append({"role": "user", "content": query})
  print("Assistant: ", end="", flush=True)

  response = ""
  for new_text in chat_model.stream_chat(messages):
    print(new_text, end="", flush=True)
    response += new_text
  print()
  messages.append({"role": "assistant", "content": response})

torch_gc()

# %% [markdown]
# ## Merge the LoRA adapter and optionally upload model
#
# NOTE: the Colab free version has merely 12GB RAM, where merging LoRA of a 8B model needs at least 18GB RAM, thus you **cannot** perform it in the free version.

# %%
# !huggingface-cli login

# %%
import json

args = dict(
  model_name_or_path="meta-llama/Meta-Llama-3-8B-Instruct", # use official non-quantized Llama-3-8B-Instruct model
  adapter_name_or_path="llama3_lora",                       # load the saved LoRA adapters
  template="llama3",                                        # same to the one in training
  finetuning_type="lora",                                   # same to the one in training
  export_dir="llama3_lora_merged",                          # the path to save the merged model
  export_size=2,                                            # the file shard size (in GB) of the merged model
  export_device="cpu",                                      # the device used in export, can be chosen from `cpu` and `auto`
  # export_hub_model_id="your_id/your_model",               # the Hugging Face hub ID to upload model
)

json.dump(args, open("merge_llama3.json", "w", encoding="utf-8"), indent=2)

# %cd /content/LLaMA-Factory/

# !llamafactory-cli export merge_llama3.json
