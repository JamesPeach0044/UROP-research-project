# %%
from datasets import load_dataset
from huggingface_hub import list_repo_files
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# %% [markdown]
# https://huggingface.co/datasets/Muennighoff/natural-instructions

# %%
print(list_repo_files("Muennighoff/natural-instructions", repo_type="dataset")[:20])
# Out:
# ['.gitattributes', 'README.md', 'get_ni.py', 'test/task020_mctaco_span_based_question_test.jsonl', 'test/task033_winogrande_answer_generation_test.jsonl', 'test/task034_winogrande_question_modification_object_test.jsonl', 'test/task035_winogrande_question_modification_person_test.jsonl', 'test/task036_qasc_topic_word_to_generate_related_fact_test.jsonl', 'test/task039_qasc_find_overlapping_words_test.jsonl', 'test/task050_multirc_answerability_test.jsonl', 'test/task102_commongen_sentence_generation_test.jsonl', 'test/task1152_bard_analogical_reasoning_causation_test.jsonl', 'test/task1153_bard_analogical_reasoning_affordance_test.jsonl', 'test/task1154_bard_analogical_reasoning_travel_test.jsonl', 'test/task1155_bard_analogical_reasoning_trash_or_treasure_test.jsonl', 'test/task1156_bard_analogical_reasoning_tools_test.jsonl', 'test/task1157_bard_analogical_reasoning_rooms_for_containers_test.jsonl', 'test/task1158_bard_analogical_reasoning_manipulating_items_test.jsonl', 'test/task1159_bard_analogical_reasoning_containers_test.jsonl', 'test/task1161_coda19_title_generation_test.jsonl']

# %%
dataset = load_dataset(
    "Muennighoff/natural-instructions"
)

print(dataset)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/39.7k [00:00<?, ?B/s]
# Resolving data files:   0%|          | 0/757 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/119 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/757 [00:00<?, ?files/s]
# train/task001_quoref_question_generation(…):   0%|          | 0.00/65.5M [00:00<?, ?B/s]
# train/task002_quoref_answer_generation_t(…):   0%|          | 0.00/19.1M [00:00<?, ?B/s]
# train/task022_cosmosqa_passage_inappropr(…):   0%|          | 0.00/94.5k [00:00<?, ?B/s]
# train/task023_cosmosqa_question_generati(…):   0%|          | 0.00/12.7M [00:00<?, ?B/s]
# train/task024_cosmosqa_answer_generation(…):   0%|          | 0.00/9.33M [00:00<?, ?B/s]
# train/task025_cosmosqa_incorrect_answer_(…):   0%|          | 0.00/19.8M [00:00<?, ?B/s]
# train/task026_drop_question_generation_t(…):   0%|          | 0.00/216M [00:00<?, ?B/s]
# train/task027_drop_answer_type_generatio(…):   0%|          | 0.00/8.03M [00:00<?, ?B/s]
# train/task028_drop_answer_generation_tra(…):   0%|          | 0.00/16.2M [00:00<?, ?B/s]
# train/task043_essential_terms_answering_(…):   0%|          | 0.00/1.87M [00:00<?, ?B/s]
# train/task044_essential_terms_identifyin(…):   0%|          | 0.00/3.04M [00:00<?, ?B/s]
# train/task045_miscellaneous_sentence_par(…):   0%|          | 0.00/1.76M [00:00<?, ?B/s]
# train/task046_miscellaneous_question_typ(…):   0%|          | 0.00/30.2M [00:00<?, ?B/s]
# train/task047_miscellaneous_answering_sc(…):   0%|          | 0.00/227k [00:00<?, ?B/s]
# train/task059_ropes_story_generation_tra(…):   0%|          | 0.00/3.24M [00:00<?, ?B/s]
# train/task060_ropes_question_generation_(…):   0%|          | 0.00/29.0M [00:00<?, ?B/s]
# train/task061_ropes_answer_generation_tr(…):   0%|          | 0.00/14.4M [00:00<?, ?B/s]
# train/task062_bigbench_repeat_copy_logic(…):   0%|          | 0.00/14.0k [00:00<?, ?B/s]
# train/task063_first_i_elements_train.jso(…):   0%|          | 0.00/3.12M [00:00<?, ?B/s]
# train/task064_all_elements_except_first_(…):   0%|          | 0.00/3.31M [00:00<?, ?B/s]
# train/task065_timetravel_consistent_sent(…):   0%|          | 0.00/6.62M [00:00<?, ?B/s]
# train/task066_timetravel_binary_consiste(…):   0%|          | 0.00/6.64M [00:00<?, ?B/s]
# train/task067_abductivenli_answer_genera(…):   0%|          | 0.00/20.7M [00:00<?, ?B/s]
# train/task068_abductivenli_incorrect_ans(…):   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# train/task069_abductivenli_classificatio(…):   0%|          | 0.00/4.32M [00:00<?, ?B/s]
# train/task070_abductivenli_incorrect_cla(…):   0%|          | 0.00/4.38M [00:00<?, ?B/s]
# train/task071_abductivenli_answer_genera(…):   0%|          | 0.00/4.54M [00:00<?, ?B/s]
# train/task072_abductivenli_answer_genera(…):   0%|          | 0.00/4.76M [00:00<?, ?B/s]
# train/task073_commonsenseqa_answer_gener(…):   0%|          | 0.00/891k [00:00<?, ?B/s]
# train/task074_squad1.1_question_generati(…):   0%|          | 0.00/44.1M [00:00<?, ?B/s]
# train/task075_squad1.1_answer_generation(…):   0%|          | 0.00/9.48M [00:00<?, ?B/s]
# train/task076_splash_correcting_sql_mist(…):   0%|          | 0.00/5.82M [00:00<?, ?B/s]
# train/task077_splash_explanation_to_sql_(…):   0%|          | 0.00/9.79M [00:00<?, ?B/s]
# train/task078_all_elements_except_last_i(…):   0%|          | 0.00/3.32M [00:00<?, ?B/s]
# train/task079_conala_concat_strings_trai(…):   0%|          | 0.00/1.50M [00:00<?, ?B/s]
# train/task080_piqa_answer_generation_tra(…):   0%|          | 0.00/3.90M [00:00<?, ?B/s]
# train/task081_piqa_wrong_answer_generati(…):   0%|          | 0.00/6.42M [00:00<?, ?B/s]
# train/task082_babi_t1_single_supporting_(…):   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/task083_babi_t1_single_supporting_(…):   0%|          | 0.00/738k [00:00<?, ?B/s]
# train/task084_babi_t1_single_supporting_(…):   0%|          | 0.00/711k [00:00<?, ?B/s]
# train/task085_unnatural_addsub_arithmeti(…):   0%|          | 0.00/2.82M [00:00<?, ?B/s]
# train/task087_new_operator_addsub_arithm(…):   0%|          | 0.00/3.29M [00:00<?, ?B/s]
# train/task088_identify_typo_verification(…):   0%|          | 0.00/4.41M [00:00<?, ?B/s]
# train/task089_swap_words_verification_tr(…):   0%|          | 0.00/3.54M [00:00<?, ?B/s]
# train/task090_equation_learner_algebra_t(…):   0%|          | 0.00/3.59M [00:00<?, ?B/s]
# train/task091_all_elements_from_index_i_(…):   0%|          | 0.00/3.71M [00:00<?, ?B/s]
# train/task092_check_prime_classification(…):   0%|          | 0.00/2.32M [00:00<?, ?B/s]
# train/task093_conala_normalize_lists_tra(…):   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# train/task094_conala_calculate_mean_trai(…):   0%|          | 0.00/2.36M [00:00<?, ?B/s]
# train/task095_conala_max_absolute_value_(…):   0%|          | 0.00/4.16M [00:00<?, ?B/s]
# train/task096_conala_list_index_subtract(…):   0%|          | 0.00/3.67M [00:00<?, ?B/s]
# train/task097_conala_remove_duplicates_t(…):   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# train/task098_conala_list_intersection_t(…):   0%|          | 0.00/3.68M [00:00<?, ?B/s]
# train/task099_reverse_elements_between_i(…):   0%|          | 0.00/3.89M [00:00<?, ?B/s]
# train/task100_concatenate_all_elements_f(…):   0%|          | 0.00/3.98M [00:00<?, ?B/s]
# train/task101_reverse_and_concatenate_al(…):   0%|          | 0.00/5.09M [00:00<?, ?B/s]
# train/task103_facts2story_long_text_gene(…):   0%|          | 0.00/20.6M [00:00<?, ?B/s]
# train/task104_semeval_2019_task10_closed(…):   0%|          | 0.00/773k [00:00<?, ?B/s]
# train/task105_story_cloze-rocstories_sen(…):   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# train/task107_splash_question_to_sql_tra(…):   0%|          | 0.00/5.11M [00:00<?, ?B/s]
# train/task1087_two_number_sum_train.json(…):   0%|          | 0.00/396k [00:00<?, ?B/s]
# train/task1088_array_of_products_train.j(…):   0%|          | 0.00/132k [00:00<?, ?B/s]
# train/task1089_check_monotonic_array_tra(…):   0%|          | 0.00/94.5k [00:00<?, ?B/s]
# train/task108_contextualabusedetection_c(…):   0%|          | 0.00/6.57M [00:00<?, ?B/s]
# train/task109_smsspamcollection_spamsmsd(…):   0%|          | 0.00/691k [00:00<?, ?B/s]
# train/task110_logic2text_sentence_genera(…):   0%|          | 0.00/17.4M [00:00<?, ?B/s]
# train/task111_asset_sentence_simplificat(…):   0%|          | 0.00/11.1M [00:00<?, ?B/s]
# train/task112_asset_simple_sentence_iden(…):   0%|          | 0.00/5.09M [00:00<?, ?B/s]
# train/task1135_xcsr_en_commonsense_mc_cl(…):   0%|          | 0.00/527k [00:00<?, ?B/s]
# train/task113_count_frequency_of_letter_(…):   0%|          | 0.00/2.25M [00:00<?, ?B/s]
# train/task1146_country_capital_train.jso(…):   0%|          | 0.00/60.2k [00:00<?, ?B/s]
# train/task1147_country_currency_train.js(…):   0%|          | 0.00/58.0k [00:00<?, ?B/s]
# train/task1148_maximum_ascii_value_train(…):   0%|          | 0.00/107k [00:00<?, ?B/s]
# train/task1149_item_check_edible_train.j(…):   0%|          | 0.00/33.0k [00:00<?, ?B/s]
# train/task114_is_the_given_word_longest_(…):   0%|          | 0.00/3.63M [00:00<?, ?B/s]
# train/task1150_delete_max_min_train.json(…):   0%|          | 0.00/104k [00:00<?, ?B/s]
# train/task1151_swap_max_min_train.jsonl:   0%|          | 0.00/97.2k [00:00<?, ?B/s]
# train/task115_help_advice_classification(…):   0%|          | 0.00/5.05M [00:00<?, ?B/s]
# train/task1167_penn_treebank_coarse_pos_(…):   0%|          | 0.00/15.5M [00:00<?, ?B/s]
# train/task1168_brown_coarse_pos_tagging_(…):   0%|          | 0.00/15.5M [00:00<?, ?B/s]
# train/task116_com2sense_commonsense_reas(…):   0%|          | 0.00/963k [00:00<?, ?B/s]
# train/task1186_nne_hrngo_classification_(…):   0%|          | 0.00/1.70M [00:00<?, ?B/s]
# train/task1188_count_max_freq_char_train(…):   0%|          | 0.00/82.7k [00:00<?, ?B/s]
# train/task1189_check_char_in_string_trai(…):   0%|          | 0.00/69.6k [00:00<?, ?B/s]
# train/task118_semeval_2019_task10_open_v(…):   0%|          | 0.00/265k [00:00<?, ?B/s]
# train/task1190_add_integer_to_list_train(…):   0%|          | 0.00/94.9k [00:00<?, ?B/s]
# train/task1191_food_veg_nonveg_train.jso(…):   0%|          | 0.00/35.3k [00:00<?, ?B/s]
# train/task1192_food_flavor_profile_train(…):   0%|          | 0.00/59.8k [00:00<?, ?B/s]
# train/task1193_food_course_classificatio(…):   0%|          | 0.00/67.6k [00:00<?, ?B/s]
# train/task1194_kth_largest_element_train(…):   0%|          | 0.00/74.0k [00:00<?, ?B/s]
# train/task1196_atomic_classification_oef(…):   0%|          | 0.00/6.03M [00:00<?, ?B/s]
# train/task1197_atomic_classification_ore(…):   0%|          | 0.00/6.45M [00:00<?, ?B/s]
# train/task1198_atomic_classification_owa(…):   0%|          | 0.00/6.40M [00:00<?, ?B/s]
# train/task1199_atomic_classification_xat(…):   0%|          | 0.00/7.01M [00:00<?, ?B/s]
# train/task119_semeval_2019_task10_geomet(…):   0%|          | 0.00/123k [00:00<?, ?B/s]
# train/task1200_atomic_classification_xef(…):   0%|          | 0.00/5.53M [00:00<?, ?B/s]
# train/task1201_atomic_classification_xin(…):   0%|          | 0.00/6.29M [00:00<?, ?B/s]
# train/task1202_atomic_classification_xne(…):   0%|          | 0.00/5.98M [00:00<?, ?B/s]
# train/task1203_atomic_classification_xre(…):   0%|          | 0.00/6.20M [00:00<?, ?B/s]
# train/task1204_atomic_classification_hin(…):   0%|          | 0.00/6.36M [00:00<?, ?B/s]
# train/task1205_atomic_classification_isa(…):   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# train/task1206_atomic_classification_isb(…):   0%|          | 0.00/4.87M [00:00<?, ?B/s]
# train/task1207_atomic_classification_atl(…):   0%|          | 0.00/4.86M [00:00<?, ?B/s]
# train/task1208_atomic_classification_xre(…):   0%|          | 0.00/645k [00:00<?, ?B/s]
# train/task1209_atomic_classification_obj(…):   0%|          | 0.00/6.23M [00:00<?, ?B/s]
# train/task1210_atomic_classification_mad(…):   0%|          | 0.00/3.93M [00:00<?, ?B/s]
# train/task1211_atomic_classification_has(…):   0%|          | 0.00/5.35M [00:00<?, ?B/s]
# train/task1212_atomic_classification_has(…):   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# train/task1213_atomic_classification_des(…):   0%|          | 0.00/4.43M [00:00<?, ?B/s]
# train/task1214_atomic_classification_xwa(…):   0%|          | 0.00/6.15M [00:00<?, ?B/s]
# train/task1215_atomic_classification_cap(…):   0%|          | 0.00/6.23M [00:00<?, ?B/s]
# train/task1216_atomic_classification_cau(…):   0%|          | 0.00/501k [00:00<?, ?B/s]
# train/task1217_atomic_answer_generation_(…):   0%|          | 0.00/13.9M [00:00<?, ?B/s]
# train/task122_conala_list_index_addition(…):   0%|          | 0.00/4.72M [00:00<?, ?B/s]
# train/task123_conala_sort_dictionary_tra(…):   0%|          | 0.00/4.53M [00:00<?, ?B/s]
# train/task124_conala_pair_averages_train(…):   0%|          | 0.00/2.79M [00:00<?, ?B/s]
# train/task125_conala_pair_differences_tr(…):   0%|          | 0.00/2.28M [00:00<?, ?B/s]
# train/task126_scan_structured_text_gener(…):   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# train/task127_scan_long_text_generation_(…):   0%|          | 0.00/23.0M [00:00<?, ?B/s]
# train/task1283_hrngo_quality_classificat(…):   0%|          | 0.00/2.02M [00:00<?, ?B/s]
# train/task1284_hrngo_informativeness_cla(…):   0%|          | 0.00/978k [00:00<?, ?B/s]
# train/task1285_kpa_keypoint_matching_tra(…):   0%|          | 0.00/4.09M [00:00<?, ?B/s]
# train/task1286_openbookqa_question_answe(…):   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# train/task1288_glue_mrpc_paraphrasing_tr(…):   0%|          | 0.00/2.27M [00:00<?, ?B/s]
# train/task1289_trec_classification_train(…):   0%|          | 0.00/4.77M [00:00<?, ?B/s]
# train/task128_scan_structured_text_gener(…):   0%|          | 0.00/9.92M [00:00<?, ?B/s]
# train/task1290_xsum_summarization_train.(…):   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# train/task1291_multi_news_summarization_(…):   0%|          | 0.00/83.9M [00:00<?, ?B/s]
# train/task1292_yelp_review_full_text_cat(…):   0%|          | 0.00/6.59M [00:00<?, ?B/s]
# train/task1293_kilt_tasks_hotpotqa_quest(…):   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# train/task1294_wiki_qa_answer_verificati(…):   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# train/task1295_adversarial_qa_question_a(…):   0%|          | 0.00/7.25M [00:00<?, ?B/s]
# train/task1296_wiki_hop_question_answeri(…):   0%|          | 0.00/51.8M [00:00<?, ?B/s]
# train/task129_scan_long_text_generation_(…):   0%|          | 0.00/22.8M [00:00<?, ?B/s]
# train/task1308_amazonreview_category_cla(…):   0%|          | 0.00/5.17M [00:00<?, ?B/s]
# train/task1309_amazonreview_summary_clas(…):   0%|          | 0.00/4.77M [00:00<?, ?B/s]
# train/task130_scan_structured_text_gener(…):   0%|          | 0.00/6.71M [00:00<?, ?B/s]
# train/task1310_amazonreview_rating_class(…):   0%|          | 0.00/4.55M [00:00<?, ?B/s]
# train/task1311_amazonreview_rating_class(…):   0%|          | 0.00/3.83M [00:00<?, ?B/s]
# train/task1312_amazonreview_polarity_cla(…):   0%|          | 0.00/4.17M [00:00<?, ?B/s]
# train/task1313_amazonreview_polarity_cla(…):   0%|          | 0.00/2.00M [00:00<?, ?B/s]
# train/task1314_country_abbreviation_trai(…):   0%|          | 0.00/62.8k [00:00<?, ?B/s]
# train/task1315_find_range_array_train.js(…):   0%|          | 0.00/83.7k [00:00<?, ?B/s]
# train/task1316_remove_duplicates_string_(…):   0%|          | 0.00/68.5k [00:00<?, ?B/s]
# train/task1317_country_calling_code_trai(…):   0%|          | 0.00/95.6k [00:00<?, ?B/s]
# train/task1318_country_national_dish_tra(…):   0%|          | 0.00/65.2k [00:00<?, ?B/s]
# train/task1319_country_by_barcode_prefix(…):   0%|          | 0.00/106k [00:00<?, ?B/s]
# train/task131_scan_long_text_generation_(…):   0%|          | 0.00/6.72M [00:00<?, ?B/s]
# train/task1320_country_domain_tld_train.(…):   0%|          | 0.00/109k [00:00<?, ?B/s]
# train/task1321_country_continent_train.j(…):   0%|          | 0.00/63.6k [00:00<?, ?B/s]
# train/task1322_country_government_type_t(…):   0%|          | 0.00/125k [00:00<?, ?B/s]
# train/task1325_qa_zre_question_generatio(…):   0%|          | 0.00/3.85M [00:00<?, ?B/s]
# train/task1326_qa_zre_question_generatio(…):   0%|          | 0.00/3.23M [00:00<?, ?B/s]
# train/task1327_qa_zre_answer_generation_(…):   0%|          | 0.00/3.03M [00:00<?, ?B/s]
# train/task1328_qa_zre_relation_generatio(…):   0%|          | 0.00/5.32M [00:00<?, ?B/s]
# train/task132_dais_text_modification_tra(…):   0%|          | 0.00/2.24M [00:00<?, ?B/s]
# train/task1331_reverse_array_train.jsonl:   0%|          | 0.00/89.6k [00:00<?, ?B/s]
# train/task1332_check_leap_year_train.jso(…):   0%|          | 0.00/92.0k [00:00<?, ?B/s]
# train/task1333_check_validity_date_ddmmy(…):   0%|          | 0.00/147k [00:00<?, ?B/s]
# train/task1336_peixian_equity_evaluation(…):   0%|          | 0.00/2.56M [00:00<?, ?B/s]
# train/task1338_peixian_equity_evaluation(…):   0%|          | 0.00/2.77M [00:00<?, ?B/s]
# train/task1339_peixian_equity_evaluation(…):   0%|          | 0.00/885k [00:00<?, ?B/s]
# train/task1340_msr_text_compression_comp(…):   0%|          | 0.00/2.70M [00:00<?, ?B/s]
# train/task1341_msr_text_classification_t(…):   0%|          | 0.00/96.0k [00:00<?, ?B/s]
# train/task1346_glue_cola_grammatical_cor(…):   0%|          | 0.00/2.05M [00:00<?, ?B/s]
# train/task1347_glue_sts-b_similarity_cla(…):   0%|          | 0.00/2.47M [00:00<?, ?B/s]
# train/task1354_sent_comp_classification_(…):   0%|          | 0.00/563k [00:00<?, ?B/s]
# train/task1355_sent_comp_summarization_t(…):   0%|          | 0.00/506k [00:00<?, ?B/s]
# train/task1359_numer_sense_answer_genera(…):   0%|          | 0.00/2.33M [00:00<?, ?B/s]
# train/task1360_numer_sense_multiple_choi(…):   0%|          | 0.00/3.05M [00:00<?, ?B/s]
# train/task1361_movierationales_classific(…):   0%|          | 0.00/8.35M [00:00<?, ?B/s]
# train/task1364_hans_answer_generation_tr(…):   0%|          | 0.00/1.60M [00:00<?, ?B/s]
# train/task1366_healthfact_classification(…):   0%|          | 0.00/1.26M [00:00<?, ?B/s]
# train/task1368_healthfact_sentence_gener(…):   0%|          | 0.00/13.7M [00:00<?, ?B/s]
# train/task1369_healthfact_sentence_gener(…):   0%|          | 0.00/15.8M [00:00<?, ?B/s]
# train/task1378_quarel_correct_answer_gen(…):   0%|          | 0.00/467k [00:00<?, ?B/s]
# train/task1379_quarel_incorrect_answer_g(…):   0%|          | 0.00/451k [00:00<?, ?B/s]
# train/task137_detoxifying-lms_classifica(…):   0%|          | 0.00/315k [00:00<?, ?B/s]
# train/task1380_quarel_correct_option_gen(…):   0%|          | 0.00/445k [00:00<?, ?B/s]
# train/task1381_quarel_incorrect_option_g(…):   0%|          | 0.00/433k [00:00<?, ?B/s]
# train/task1382_quarel_write_correct_answ(…):   0%|          | 0.00/366k [00:00<?, ?B/s]
# train/task1383_quarel_write_incorrect_an(…):   0%|          | 0.00/493k [00:00<?, ?B/s]
# train/task1384_deal_or_no_dialog_classif(…):   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/task1389_hellaswag_completion_trai(…):   0%|          | 0.00/7.61M [00:00<?, ?B/s]
# train/task138_detoxifying-lms_classifica(…):   0%|          | 0.00/307k [00:00<?, ?B/s]
# train/task1398_obqa_question_generation_(…):   0%|          | 0.00/427k [00:00<?, ?B/s]
# train/task1399_obqa_answer_generation_tr(…):   0%|          | 0.00/881k [00:00<?, ?B/s]
# train/task139_detoxifying-lms_classifica(…):   0%|          | 0.00/358k [00:00<?, ?B/s]
# train/task1400_obqa_incorrect_answer_gen(…):   0%|          | 0.00/2.74M [00:00<?, ?B/s]
# train/task1401_obqa_sentence_generation_(…):   0%|          | 0.00/797k [00:00<?, ?B/s]
# train/task1403_check_validity_date_mmddy(…):   0%|          | 0.00/175k [00:00<?, ?B/s]
# train/task1404_date_conversion_train.jso(…):   0%|          | 0.00/81.7k [00:00<?, ?B/s]
# train/task1405_find_median_train.jsonl:   0%|          | 0.00/110k [00:00<?, ?B/s]
# train/task1406_kth_smallest_element_trai(…):   0%|          | 0.00/76.0k [00:00<?, ?B/s]
# train/task140_detoxifying-lms_classifica(…):   0%|          | 0.00/360k [00:00<?, ?B/s]
# train/task1412_web_questions_question_an(…):   0%|          | 0.00/2.76M [00:00<?, ?B/s]
# train/task1418_bless_semantic_relation_c(…):   0%|          | 0.00/2.68M [00:00<?, ?B/s]
# train/task1419_mathqa_gain_train.jsonl:   0%|          | 0.00/3.66M [00:00<?, ?B/s]
# train/task141_odd-man-out_classification(…):   0%|          | 0.00/2.75M [00:00<?, ?B/s]
# train/task1420_mathqa_general_train.json(…):   0%|          | 0.00/3.34M [00:00<?, ?B/s]
# train/task1421_mathqa_other_train.jsonl:   0%|          | 0.00/1.09M [00:00<?, ?B/s]
# train/task1422_mathqa_physics_train.json(…):   0%|          | 0.00/3.44M [00:00<?, ?B/s]
# train/task1423_mathqa_geometry_train.jso(…):   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# train/task1424_mathqa_probability_train.(…):   0%|          | 0.00/289k [00:00<?, ?B/s]
# train/task1425_country_iso_numeric_train(…):   0%|          | 0.00/113k [00:00<?, ?B/s]
# train/task1426_country_independence_year(…):   0%|          | 0.00/87.0k [00:00<?, ?B/s]
# train/task1427_country_region_in_world_t(…):   0%|          | 0.00/175k [00:00<?, ?B/s]
# train/task1428_country_surface_area_trai(…):   0%|          | 0.00/80.6k [00:00<?, ?B/s]
# train/task1429_evalution_semantic_relati(…):   0%|          | 0.00/788k [00:00<?, ?B/s]
# train/task142_odd-man-out_classification(…):   0%|          | 0.00/2.37M [00:00<?, ?B/s]
# train/task1431_head_qa_answer_generation(…):   0%|          | 0.00/1.75M [00:00<?, ?B/s]
# train/task1434_head_qa_classification_tr(…):   0%|          | 0.00/1.88M [00:00<?, ?B/s]
# train/task143_odd-man-out_classification(…):   0%|          | 0.00/7.36M [00:00<?, ?B/s]
# train/task1443_string_to_number_train.js(…):   0%|          | 0.00/3.57M [00:00<?, ?B/s]
# train/task1444_round_power_of_two_train.(…):   0%|          | 0.00/6.18M [00:00<?, ?B/s]
# train/task1445_closest_integers_train.js(…):   0%|          | 0.00/3.07M [00:00<?, ?B/s]
# train/task1446_farthest_integers_train.j(…):   0%|          | 0.00/3.08M [00:00<?, ?B/s]
# train/task1447_drug_extraction_ade_train(…):   0%|          | 0.00/1.72M [00:00<?, ?B/s]
# train/task1448_disease_entity_extraction(…):   0%|          | 0.00/108k [00:00<?, ?B/s]
# train/task1449_disease_entity_extraction(…):   0%|          | 0.00/58.1k [00:00<?, ?B/s]
# train/task144_subjqa_question_answering_(…):   0%|          | 0.00/1.37M [00:00<?, ?B/s]
# train/task1451_drug_dose_extraction_trai(…):   0%|          | 0.00/135k [00:00<?, ?B/s]
# train/task1452_location_entity_extractio(…):   0%|          | 0.00/85.3k [00:00<?, ?B/s]
# train/task1453_person_entity_extraction_(…):   0%|          | 0.00/139k [00:00<?, ?B/s]
# train/task145_afs_argument_similarity_de(…):   0%|          | 0.00/1.71M [00:00<?, ?B/s]
# train/task146_afs_argument_similarity_gu(…):   0%|          | 0.00/1.82M [00:00<?, ?B/s]
# train/task1479_organization_entity_extra(…):   0%|          | 0.00/96.4k [00:00<?, ?B/s]
# train/task147_afs_argument_similarity_ga(…):   0%|          | 0.00/1.42M [00:00<?, ?B/s]
# train/task1480_gene_extraction_jnlpba_da(…):   0%|          | 0.00/618k [00:00<?, ?B/s]
# train/task1481_gene_extraction_bc2gm_dat(…):   0%|          | 0.00/549k [00:00<?, ?B/s]
# train/task1482_gene_extraction_chemprot_(…):   0%|          | 0.00/131k [00:00<?, ?B/s]
# train/task1483_chemical_extraction_chemp(…):   0%|          | 0.00/138k [00:00<?, ?B/s]
# train/task1484_gene_extraction_linnaeus_(…):   0%|          | 0.00/73.1k [00:00<?, ?B/s]
# train/task1485_organ_extraction_anem_dat(…):   0%|          | 0.00/90.0k [00:00<?, ?B/s]
# train/task1486_cell_extraction_anem_data(…):   0%|          | 0.00/86.0k [00:00<?, ?B/s]
# train/task1487_organism_substance_extrac(…):   0%|          | 0.00/61.1k [00:00<?, ?B/s]
# train/task1488_sarcasmdetection_headline(…):   0%|          | 0.00/290k [00:00<?, ?B/s]
# train/task1489_sarcasmdetection_tweet_cl(…):   0%|          | 0.00/69.4k [00:00<?, ?B/s]
# train/task148_afs_argument_quality_gay_m(…):   0%|          | 0.00/934k [00:00<?, ?B/s]
# train/task1495_adverse_drug_event_classi(…):   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# train/task1498_24hour_to_12hour_clock_tr(…):   0%|          | 0.00/146k [00:00<?, ?B/s]
# train/task1499_dstc3_summarization_train(…):   0%|          | 0.00/4.71M [00:00<?, ?B/s]
# train/task149_afs_argument_quality_death(…):   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# train/task1500_dstc3_classification_trai(…):   0%|          | 0.00/2.00M [00:00<?, ?B/s]
# train/task1501_dstc3_answer_generation_t(…):   0%|          | 0.00/2.80M [00:00<?, ?B/s]
# train/task1502_hatexplain_classification(…):   0%|          | 0.00/3.34M [00:00<?, ?B/s]
# train/task1503_hatexplain_classification(…):   0%|          | 0.00/632k [00:00<?, ?B/s]
# train/task1504_hatexplain_answer_generat(…):   0%|          | 0.00/2.51M [00:00<?, ?B/s]
# train/task1505_root09_semantic_relation_(…):   0%|          | 0.00/1.90M [00:00<?, ?B/s]
# train/task1506_celebrity_minimal_dob_spa(…):   0%|          | 0.00/156k [00:00<?, ?B/s]
# train/task1507_boolean_temporal_reasonin(…):   0%|          | 0.00/5.43M [00:00<?, ?B/s]
# train/task1508_wordnet_antonyms_train.js(…):   0%|          | 0.00/871k [00:00<?, ?B/s]
# train/task1509_evalution_antonyms_train.(…):   0%|          | 0.00/162k [00:00<?, ?B/s]
# train/task150_afs_argument_quality_gun_c(…):   0%|          | 0.00/1.57M [00:00<?, ?B/s]
# train/task1510_evalution_relation_extrac(…):   0%|          | 0.00/3.37M [00:00<?, ?B/s]
# train/task1517_limit_classfication_train(…):   0%|          | 0.00/1.70M [00:00<?, ?B/s]
# train/task1518_limit_answer_generation_t(…):   0%|          | 0.00/973k [00:00<?, ?B/s]
# train/task1519_qa_srl_question_generatio(…):   0%|          | 0.00/900k [00:00<?, ?B/s]
# train/task151_tomqa_find_location_easy_c(…):   0%|          | 0.00/5.50M [00:00<?, ?B/s]
# train/task1520_qa_srl_answer_generation_(…):   0%|          | 0.00/551k [00:00<?, ?B/s]
# train/task152_tomqa_find_location_easy_n(…):   0%|          | 0.00/6.59M [00:00<?, ?B/s]
# train/task153_tomqa_find_location_hard_c(…):   0%|          | 0.00/9.36M [00:00<?, ?B/s]
# train/task1541_agnews_classification_tra(…):   0%|          | 0.00/3.45M [00:00<?, ?B/s]
# train/task1542_every_ith_element_from_st(…):   0%|          | 0.00/3.30M [00:00<?, ?B/s]
# train/task1548_wiqa_binary_classificatio(…):   0%|          | 0.00/562k [00:00<?, ?B/s]
# train/task1549_wiqa_answer_generation_mi(…):   0%|          | 0.00/86.8k [00:00<?, ?B/s]
# train/task154_tomqa_find_location_hard_n(…):   0%|          | 0.00/10.5M [00:00<?, ?B/s]
# train/task1551_every_ith_element_from_kt(…):   0%|          | 0.00/3.54M [00:00<?, ?B/s]
# train/task1553_cnn_dailymail_summarizati(…):   0%|          | 0.00/4.29M [00:00<?, ?B/s]
# train/task1559_blimp_binary_classificati(…):   0%|          | 0.00/660k [00:00<?, ?B/s]
# train/task155_count_nouns_verbs_train.js(…):   0%|          | 0.00/2.12M [00:00<?, ?B/s]
# train/task1560_blimp_binary_classificati(…):   0%|          | 0.00/1.05M [00:00<?, ?B/s]
# train/task1564_triviaqa_answer_generatio(…):   0%|          | 0.00/38.5k [00:00<?, ?B/s]
# train/task1565_triviaqa_classification_t(…):   0%|          | 0.00/54.2k [00:00<?, ?B/s]
# train/task1566_propara_structured_text_g(…):   0%|          | 0.00/183k [00:00<?, ?B/s]
# train/task1567_propara_question_generati(…):   0%|          | 0.00/178k [00:00<?, ?B/s]
# train/task1568_propara_classification_tr(…):   0%|          | 0.00/171k [00:00<?, ?B/s]
# train/task156_codah_classification_adver(…):   0%|          | 0.00/2.16M [00:00<?, ?B/s]
# train/task1572_samsum_summary_train.json(…):   0%|          | 0.00/212k [00:00<?, ?B/s]
# train/task1573_samsum_classification_tra(…):   0%|          | 0.00/163k [00:00<?, ?B/s]
# train/task157_count_vowels_and_consonant(…):   0%|          | 0.00/2.75M [00:00<?, ?B/s]
# train/task1580_eqasc-perturbed_question_(…):   0%|          | 0.00/281k [00:00<?, ?B/s]
# train/task1581_eqasc-perturbed_answer_ge(…):   0%|          | 0.00/329k [00:00<?, ?B/s]
# train/task1582_bless_hypernym_generation(…):   0%|          | 0.00/59.6k [00:00<?, ?B/s]
# train/task1583_bless_meronym_classificat(…):   0%|          | 0.00/701k [00:00<?, ?B/s]
# train/task1584_evalution_meronym_classif(…):   0%|          | 0.00/579k [00:00<?, ?B/s]
# train/task1585_root09_hypernym_generatio(…):   0%|          | 0.00/210k [00:00<?, ?B/s]
# train/task158_count_frequency_of_words_t(…):   0%|          | 0.00/750k [00:00<?, ?B/s]
# train/task1590_diplomacy_text_generation(…):   0%|          | 0.00/209k [00:00<?, ?B/s]
# train/task1592_yahoo_answers_topics_clas(…):   0%|          | 0.00/547k [00:00<?, ?B/s]
# train/task1593_yahoo_answers_topics_clas(…):   0%|          | 0.00/942k [00:00<?, ?B/s]
# train/task1594_yahoo_answers_topics_ques(…):   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/task1595_event2mind_text_generatio(…):   0%|          | 0.00/2.97M [00:00<?, ?B/s]
# train/task1596_event2mind_text_generatio(…):   0%|          | 0.00/2.97M [00:00<?, ?B/s]
# train/task1599_smcalflow_classification_(…):   0%|          | 0.00/2.26M [00:00<?, ?B/s]
# train/task159_check_frequency_of_words_i(…):   0%|          | 0.00/3.05M [00:00<?, ?B/s]
# train/task1600_smcalflow_sentence_genera(…):   0%|          | 0.00/601k [00:00<?, ?B/s]
# train/task1601_webquestions_answer_gener(…):   0%|          | 0.00/1.65M [00:00<?, ?B/s]
# train/task1602_webquestion_question_genr(…):   0%|          | 0.00/1.28M [00:00<?, ?B/s]
# train/task1603_smcalflow_sentence_genera(…):   0%|          | 0.00/1.19M [00:00<?, ?B/s]
# train/task1604_ethos_text_classification(…):   0%|          | 0.00/378k [00:00<?, ?B/s]
# train/task1605_ethos_text_classification(…):   0%|          | 0.00/147k [00:00<?, ?B/s]
# train/task1606_ethos_text_classification(…):   0%|          | 0.00/88.2k [00:00<?, ?B/s]
# train/task1607_ethos_text_classification(…):   0%|          | 0.00/100k [00:00<?, ?B/s]
# train/task1608_xquad_en_answer_generatio(…):   0%|          | 0.00/1.46M [00:00<?, ?B/s]
# train/task1609_xquad_en_question_generat(…):   0%|          | 0.00/1.46M [00:00<?, ?B/s]
# train/task160_replace_letter_in_a_senten(…):   0%|          | 0.00/2.61M [00:00<?, ?B/s]
# train/task161_count_words_containing_let(…):   0%|          | 0.00/2.36M [00:00<?, ?B/s]
# train/task162_count_words_starting_with_(…):   0%|          | 0.00/1.54M [00:00<?, ?B/s]
# train/task163_count_words_ending_with_le(…):   0%|          | 0.00/2.34M [00:00<?, ?B/s]
# train/task1645_medical_question_pair_dat(…):   0%|          | 0.00/2.04M [00:00<?, ?B/s]
# train/task164_mcscript_question_answerin(…):   0%|          | 0.00/9.06M [00:00<?, ?B/s]
# train/task1656_gooaq_answer_generation_t(…):   0%|          | 0.00/27.1k [00:00<?, ?B/s]
# train/task1657_gooaq_question_generation(…):   0%|          | 0.00/40.6k [00:00<?, ?B/s]
# train/task165_mcscript_question_answerin(…):   0%|          | 0.00/9.70M [00:00<?, ?B/s]
# train/task1660_super_glue_question_gener(…):   0%|          | 0.00/1.87M [00:00<?, ?B/s]
# train/task1661_super_glue_classification(…):   0%|          | 0.00/4.02M [00:00<?, ?B/s]
# train/task1665_trainglecopa_question_gen(…):   0%|          | 0.00/65.2k [00:00<?, ?B/s]
# train/task1669_md_gender_bias_text_modif(…):   0%|          | 0.00/431k [00:00<?, ?B/s]
# train/task166_clariq_sentence_generation(…):   0%|          | 0.00/1.74M [00:00<?, ?B/s]
# train/task1670_md_gender_bias_text_modif(…):   0%|          | 0.00/433k [00:00<?, ?B/s]
# train/task1678_mathqa_answer_selection_t(…):   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# train/task167_strategyqa_question_genera(…):   0%|          | 0.00/5.99M [00:00<?, ?B/s]
# train/task168_strategyqa_question_decomp(…):   0%|          | 0.00/9.58M [00:00<?, ?B/s]
# train/task169_strategyqa_sentence_genera(…):   0%|          | 0.00/3.40M [00:00<?, ?B/s]
# train/task1703_ljspeech_textmodification(…):   0%|          | 0.00/378k [00:00<?, ?B/s]
# train/task1704_ljspeech_textmodification(…):   0%|          | 0.00/262k [00:00<?, ?B/s]
# train/task1705_ljspeech_classification_t(…):   0%|          | 0.00/56.8k [00:00<?, ?B/s]
# train/task1706_ljspeech_classification_t(…):   0%|          | 0.00/52.6k [00:00<?, ?B/s]
# train/task170_hotpotqa_answer_generation(…):   0%|          | 0.00/42.3M [00:00<?, ?B/s]
# train/task1711_poki_text_generation_trai(…):   0%|          | 0.00/5.31M [00:00<?, ?B/s]
# train/task1712_poki_classification_train(…):   0%|          | 0.00/5.23M [00:00<?, ?B/s]
# train/task1713_convai3_sentence_generati(…):   0%|          | 0.00/118k [00:00<?, ?B/s]
# train/task1714_convai3_sentence_generati(…):   0%|          | 0.00/1.89M [00:00<?, ?B/s]
# train/task1720_civil_comments_toxicity_c(…):   0%|          | 0.00/630k [00:00<?, ?B/s]
# train/task1721_civil_comments_obscenity_(…):   0%|          | 0.00/563k [00:00<?, ?B/s]
# train/task1722_civil_comments_threat_cla(…):   0%|          | 0.00/572k [00:00<?, ?B/s]
# train/task1723_civil_comments_sexuallyex(…):   0%|          | 0.00/639k [00:00<?, ?B/s]
# train/task1724_civil_comments_insult_cla(…):   0%|          | 0.00/602k [00:00<?, ?B/s]
# train/task1725_civil_comments_severtoxic(…):   0%|          | 0.00/604k [00:00<?, ?B/s]
# train/task1726_mathqa_correct_answer_gen(…):   0%|          | 0.00/1.82M [00:00<?, ?B/s]
# train/task1727_wiqa_what_is_the_effect_t(…):   0%|          | 0.00/6.35M [00:00<?, ?B/s]
# train/task1729_personachat_generate_next(…):   0%|          | 0.00/6.96M [00:00<?, ?B/s]
# train/task1730_personachat_choose_next_t(…):   0%|          | 0.00/7.59M [00:00<?, ?B/s]
# train/task1731_quartz_question_answering(…):   0%|          | 0.00/1.57M [00:00<?, ?B/s]
# train/task176_break_decompose_questions_(…):   0%|          | 0.00/18.1M [00:00<?, ?B/s]
# train/task177_para-nmt_paraphrasing_trai(…):   0%|          | 0.00/2.98M [00:00<?, ?B/s]
# train/task178_quartz_question_answering_(…):   0%|          | 0.00/2.75M [00:00<?, ?B/s]
# train/task179_participant_extraction_tra(…):   0%|          | 0.00/379k [00:00<?, ?B/s]
# train/task180_intervention_extraction_tr(…):   0%|          | 0.00/420k [00:00<?, ?B/s]
# train/task181_outcome_extraction_train.j(…):   0%|          | 0.00/512k [00:00<?, ?B/s]
# train/task182_duorc_question_generation_(…):   0%|          | 0.00/377M [00:00<?, ?B/s]
# train/task183_rhyme_generation_train.jso(…):   0%|          | 0.00/14.6M [00:00<?, ?B/s]
# train/task184_break_generate_question_tr(…):   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# train/task191_hotpotqa_question_generati(…):   0%|          | 0.00/42.3M [00:00<?, ?B/s]
# train/task192_hotpotqa_sentence_generati(…):   0%|          | 0.00/6.58M [00:00<?, ?B/s]
# train/task193_duorc_question_generation_(…):   0%|          | 0.00/18.3M [00:00<?, ?B/s]
# train/task194_duorc_answer_generation_tr(…):   0%|          | 0.00/27.0M [00:00<?, ?B/s]
# train/task195_sentiment140_classificatio(…):   0%|          | 0.00/2.55M [00:00<?, ?B/s]
# train/task196_sentiment140_answer_genera(…):   0%|          | 0.00/3.41M [00:00<?, ?B/s]
# train/task205_remove_even_elements_train(…):   0%|          | 0.00/2.47M [00:00<?, ?B/s]
# train/task206_collatz_conjecture_train.j(…):   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# train/task207_max_element_lists_train.js(…):   0%|          | 0.00/2.98M [00:00<?, ?B/s]
# train/task208_combinations_of_list_train(…):   0%|          | 0.00/4.00M [00:00<?, ?B/s]
# train/task209_stancedetection_classifica(…):   0%|          | 0.00/663k [00:00<?, ?B/s]
# train/task210_logic2text_structured_text(…):   0%|          | 0.00/19.9M [00:00<?, ?B/s]
# train/task211_logic2text_classification_(…):   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# train/task212_logic2text_classification_(…):   0%|          | 0.00/23.9M [00:00<?, ?B/s]
# train/task223_quartz_explanation_generat(…):   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# train/task227_clariq_classification_trai(…):   0%|          | 0.00/3.68M [00:00<?, ?B/s]
# train/task228_arc_answer_generation_easy(…):   0%|          | 0.00/3.79M [00:00<?, ?B/s]
# train/task229_arc_answer_generation_hard(…):   0%|          | 0.00/2.00M [00:00<?, ?B/s]
# train/task243_count_elements_in_set_inte(…):   0%|          | 0.00/722k [00:00<?, ?B/s]
# train/task244_count_elements_in_set_unio(…):   0%|          | 0.00/718k [00:00<?, ?B/s]
# train/task245_check_presence_in_set_inte(…):   0%|          | 0.00/2.87M [00:00<?, ?B/s]
# train/task246_dream_question_generation_(…):   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# train/task247_dream_answer_generation_tr(…):   0%|          | 0.00/6.81M [00:00<?, ?B/s]
# train/task248_dream_classification_train(…):   0%|          | 0.00/1.56M [00:00<?, ?B/s]
# train/task267_concatenate_and_reverse_al(…):   0%|          | 0.00/5.42M [00:00<?, ?B/s]
# train/task268_casehold_legal_answer_gene(…):   0%|          | 0.00/15.9M [00:00<?, ?B/s]
# train/task269_csrg_counterfactual_story_(…):   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# train/task270_csrg_counterfactual_contex(…):   0%|          | 0.00/10.2M [00:00<?, ?B/s]
# train/task274_overruling_legal_classific(…):   0%|          | 0.00/1.81M [00:00<?, ?B/s]
# train/task275_enhanced_wsc_paraphrase_ge(…):   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# train/task276_enhanced_wsc_classificatio(…):   0%|          | 0.00/1.86M [00:00<?, ?B/s]
# train/task277_stereoset_sentence_generat(…):   0%|          | 0.00/518k [00:00<?, ?B/s]
# train/task278_stereoset_sentence_generat(…):   0%|          | 0.00/403k [00:00<?, ?B/s]
# train/task279_stereoset_classification_s(…):   0%|          | 0.00/4.41M [00:00<?, ?B/s]
# train/task280_stereoset_classification_s(…):   0%|          | 0.00/2.36M [00:00<?, ?B/s]
# train/task283_dream_incorrect_answer_gen(…):   0%|          | 0.00/13.3M [00:00<?, ?B/s]
# train/task284_imdb_classification_train.(…):   0%|          | 0.00/10.5M [00:00<?, ?B/s]
# train/task285_imdb_answer_generation_tra(…):   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# train/task286_olid_offense_judgment_trai(…):   0%|          | 0.00/4.52M [00:00<?, ?B/s]
# train/task287_casehold_legal_incorrect_a(…):   0%|          | 0.00/68.7M [00:00<?, ?B/s]
# train/task291_semeval_2020_task4_commons(…):   0%|          | 0.00/3.11M [00:00<?, ?B/s]
# train/task292_storycommonsense_character(…):   0%|          | 0.00/4.01M [00:00<?, ?B/s]
# train/task293_storycommonsense_emotion_t(…):   0%|          | 0.00/10.3M [00:00<?, ?B/s]
# train/task294_storycommonsense_motiv_tex(…):   0%|          | 0.00/7.30M [00:00<?, ?B/s]
# train/task295_semeval_2020_task4_commons(…):   0%|          | 0.00/3.66M [00:00<?, ?B/s]
# train/task296_storycloze_correct_end_cla(…):   0%|          | 0.00/1.38M [00:00<?, ?B/s]
# train/task297_storycloze_incorrect_end_c(…):   0%|          | 0.00/1.50M [00:00<?, ?B/s]
# train/task298_storycloze_correct_end_cla(…):   0%|          | 0.00/2.60M [00:00<?, ?B/s]
# train/task299_storycloze_sentence_genera(…):   0%|          | 0.00/5.14M [00:00<?, ?B/s]
# train/task300_storycloze_order_generatio(…):   0%|          | 0.00/5.30M [00:00<?, ?B/s]
# train/task301_record_question_generation(…):   0%|          | 0.00/14.3M [00:00<?, ?B/s]
# train/task302_record_classification_trai(…):   0%|          | 0.00/11.1M [00:00<?, ?B/s]
# train/task303_record_incorrect_answer_ge(…):   0%|          | 0.00/108M [00:00<?, ?B/s]
# train/task305_jeopardy_answer_generation(…):   0%|          | 0.00/3.29M [00:00<?, ?B/s]
# train/task306_jeopardy_answer_generation(…):   0%|          | 0.00/3.30M [00:00<?, ?B/s]
# train/task307_jeopardy_answer_generation(…):   0%|          | 0.00/1.86M [00:00<?, ?B/s]
# train/task308_jeopardy_answer_generation(…):   0%|          | 0.00/3.27M [00:00<?, ?B/s]
# train/task309_race_answer_generation_tra(…):   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# train/task310_race_classification_train.(…):   0%|          | 0.00/16.1M [00:00<?, ?B/s]
# train/task311_race_question_generation_t(…):   0%|          | 0.00/14.4M [00:00<?, ?B/s]
# train/task316_crows-pairs_classification(…):   0%|          | 0.00/1.92M [00:00<?, ?B/s]
# train/task317_crows-pairs_classification(…):   0%|          | 0.00/894k [00:00<?, ?B/s]
# train/task318_stereoset_classification_g(…):   0%|          | 0.00/541k [00:00<?, ?B/s]
# train/task319_stereoset_classification_p(…):   0%|          | 0.00/1.88M [00:00<?, ?B/s]
# train/task320_stereoset_classification_r(…):   0%|          | 0.00/2.16M [00:00<?, ?B/s]
# train/task321_stereoset_classification_r(…):   0%|          | 0.00/167k [00:00<?, ?B/s]
# train/task322_jigsaw_classification_thre(…):   0%|          | 0.00/4.26M [00:00<?, ?B/s]
# train/task323_jigsaw_classification_sexu(…):   0%|          | 0.00/4.45M [00:00<?, ?B/s]
# train/task324_jigsaw_classification_disa(…):   0%|          | 0.00/393k [00:00<?, ?B/s]
# train/task325_jigsaw_classification_iden(…):   0%|          | 0.00/4.80M [00:00<?, ?B/s]
# train/task326_jigsaw_classification_obsc(…):   0%|          | 0.00/4.87M [00:00<?, ?B/s]
# train/task327_jigsaw_classification_toxi(…):   0%|          | 0.00/3.29M [00:00<?, ?B/s]
# train/task328_jigsaw_classification_insu(…):   0%|          | 0.00/3.78M [00:00<?, ?B/s]
# train/task333_hateeval_classification_ha(…):   0%|          | 0.00/4.44M [00:00<?, ?B/s]
# train/task335_hateeval_classification_ag(…):   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/task337_hateeval_classification_in(…):   0%|          | 0.00/1.76M [00:00<?, ?B/s]
# train/task339_record_answer_generation_t(…):   0%|          | 0.00/10.2M [00:00<?, ?B/s]
# train/task340_winomt_classification_gend(…):   0%|          | 0.00/875k [00:00<?, ?B/s]
# train/task341_winomt_classification_gend(…):   0%|          | 0.00/879k [00:00<?, ?B/s]
# train/task342_winomt_classification_prof(…):   0%|          | 0.00/863k [00:00<?, ?B/s]
# train/task343_winomt_classification_prof(…):   0%|          | 0.00/864k [00:00<?, ?B/s]
# train/task344_hybridqa_answer_generation(…):   0%|          | 0.00/2.71M [00:00<?, ?B/s]
# train/task345_hybridqa_answer_generation(…):   0%|          | 0.00/8.81M [00:00<?, ?B/s]
# train/task346_hybridqa_classification_tr(…):   0%|          | 0.00/9.34M [00:00<?, ?B/s]
# train/task347_hybridqa_incorrect_answer_(…):   0%|          | 0.00/9.77M [00:00<?, ?B/s]
# train/task350_winomt_classification_gend(…):   0%|          | 0.00/1.91M [00:00<?, ?B/s]
# train/task351_winomt_classification_gend(…):   0%|          | 0.00/1.88M [00:00<?, ?B/s]
# train/task353_casino_classification_nego(…):   0%|          | 0.00/774k [00:00<?, ?B/s]
# train/task354_casino_classification_nego(…):   0%|          | 0.00/490k [00:00<?, ?B/s]
# train/task355_casino_classification_nego(…):   0%|          | 0.00/957k [00:00<?, ?B/s]
# train/task356_casino_classification_nego(…):   0%|          | 0.00/2.23M [00:00<?, ?B/s]
# train/task357_casino_classification_nego(…):   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# train/task358_casino_classification_nego(…):   0%|          | 0.00/348k [00:00<?, ?B/s]
# train/task359_casino_classification_nego(…):   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# train/task363_sst2_polarity_classificati(…):   0%|          | 0.00/3.01M [00:00<?, ?B/s]
# train/task364_regard_social_impact_class(…):   0%|          | 0.00/206k [00:00<?, ?B/s]
# train/task365_synthetic_remove_vowels_tr(…):   0%|          | 0.00/2.23M [00:00<?, ?B/s]
# train/task366_synthetic_return_primes_tr(…):   0%|          | 0.00/3.55M [00:00<?, ?B/s]
# train/task367_synthetic_remove_floats_tr(…):   0%|          | 0.00/3.18M [00:00<?, ?B/s]
# train/task368_synthetic_even_or_odd_calc(…):   0%|          | 0.00/3.90M [00:00<?, ?B/s]
# train/task369_synthetic_remove_odds_trai(…):   0%|          | 0.00/3.22M [00:00<?, ?B/s]
# train/task370_synthetic_remove_divisible(…):   0%|          | 0.00/2.89M [00:00<?, ?B/s]
# train/task371_synthetic_product_of_list_(…):   0%|          | 0.00/3.66M [00:00<?, ?B/s]
# train/task372_synthetic_palindrome_numbe(…):   0%|          | 0.00/3.85M [00:00<?, ?B/s]
# train/task373_synthetic_round_tens_place(…):   0%|          | 0.00/2.72M [00:00<?, ?B/s]
# train/task374_synthetic_pos_or_neg_calcu(…):   0%|          | 0.00/3.81M [00:00<?, ?B/s]
# train/task375_classify_type_of_sentence_(…):   0%|          | 0.00/642k [00:00<?, ?B/s]
# train/task376_reverse_order_of_words_tra(…):   0%|          | 0.00/2.17M [00:00<?, ?B/s]
# train/task377_remove_words_of_given_leng(…):   0%|          | 0.00/3.22M [00:00<?, ?B/s]
# train/task378_reverse_words_of_given_len(…):   0%|          | 0.00/3.29M [00:00<?, ?B/s]
# train/task379_agnews_topic_classificatio(…):   0%|          | 0.00/5.08M [00:00<?, ?B/s]
# train/task380_boolq_yes_no_question_trai(…):   0%|          | 0.00/6.07M [00:00<?, ?B/s]
# train/task381_boolq_question_generation_(…):   0%|          | 0.00/3.47M [00:00<?, ?B/s]
# train/task382_hybridqa_answer_generation(…):   0%|          | 0.00/9.19M [00:00<?, ?B/s]
# train/task383_matres_classification_trai(…):   0%|          | 0.00/1.62M [00:00<?, ?B/s]
# train/task384_socialiqa_question_classif(…):   0%|          | 0.00/2.94M [00:00<?, ?B/s]
# train/task385_socialiqa_incorrect_answer(…):   0%|          | 0.00/4.40M [00:00<?, ?B/s]
# train/task386_semeval_2018_task3_irony_d(…):   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# train/task387_semeval_2018_task3_irony_c(…):   0%|          | 0.00/901k [00:00<?, ?B/s]
# train/task388_torque_token_classificatio(…):   0%|          | 0.00/18.4M [00:00<?, ?B/s]
# train/task389_torque_generate_temporal_q(…):   0%|          | 0.00/20.5M [00:00<?, ?B/s]
# train/task390_torque_text_span_selection(…):   0%|          | 0.00/14.3M [00:00<?, ?B/s]
# train/task397_semeval_2018_task1_tweet_a(…):   0%|          | 0.00/1.15M [00:00<?, ?B/s]
# train/task398_semeval_2018_task1_tweet_j(…):   0%|          | 0.00/793k [00:00<?, ?B/s]
# train/task399_semeval_2018_task1_tweet_s(…):   0%|          | 0.00/1.66M [00:00<?, ?B/s]
# train/task400_paws_paraphrase_classifica(…):   0%|          | 0.00/4.43M [00:00<?, ?B/s]
# train/task403_creak_commonsense_inferenc(…):   0%|          | 0.00/4.38M [00:00<?, ?B/s]
# train/task405_narrativeqa_question_gener(…):   0%|          | 0.00/189M [00:00<?, ?B/s]
# train/task413_mickey_en_sentence_perturb(…):   0%|          | 0.00/15.1M [00:00<?, ?B/s]
# train/task428_senteval_inversion_train.j(…):   0%|          | 0.00/3.47M [00:00<?, ?B/s]
# train/task429_senteval_tense_train.jsonl:   0%|          | 0.00/2.94M [00:00<?, ?B/s]
# train/task430_senteval_subject_count_tra(…):   0%|          | 0.00/2.64M [00:00<?, ?B/s]
# train/task431_senteval_object_count_trai(…):   0%|          | 0.00/2.83M [00:00<?, ?B/s]
# train/task453_swag_answer_generation_tra(…):   0%|          | 0.00/2.61M [00:00<?, ?B/s]
# train/task454_swag_incorrect_answer_gene(…):   0%|          | 0.00/2.65M [00:00<?, ?B/s]
# train/task455_swag_context_generation_tr(…):   0%|          | 0.00/2.62M [00:00<?, ?B/s]
# train/task456_matres_intention_classific(…):   0%|          | 0.00/2.38M [00:00<?, ?B/s]
# train/task457_matres_conditional_classif(…):   0%|          | 0.00/630k [00:00<?, ?B/s]
# train/task458_matres_negation_classifica(…):   0%|          | 0.00/580k [00:00<?, ?B/s]
# train/task459_matres_static_classificati(…):   0%|          | 0.00/70.9k [00:00<?, ?B/s]
# train/task460_qasper_answer_generation_t(…):   0%|          | 0.00/2.49M [00:00<?, ?B/s]
# train/task461_qasper_question_generation(…):   0%|          | 0.00/2.33M [00:00<?, ?B/s]
# train/task462_qasper_classification_trai(…):   0%|          | 0.00/1.69M [00:00<?, ?B/s]
# train/task469_mrqa_answer_generation_tra(…):   0%|          | 0.00/11.2M [00:00<?, ?B/s]
# train/task470_mrqa_question_generation_t(…):   0%|          | 0.00/4.74M [00:00<?, ?B/s]
# train/task471_haspart_answer_generation_(…):   0%|          | 0.00/1.58M [00:00<?, ?B/s]
# train/task472_haspart_classification_tra(…):   0%|          | 0.00/3.44M [00:00<?, ?B/s]
# train/task475_yelp_polarity_classificati(…):   0%|          | 0.00/7.16M [00:00<?, ?B/s]
# train/task476_cls_english_books_classifi(…):   0%|          | 0.00/2.66M [00:00<?, ?B/s]
# train/task477_cls_english_dvd_classifica(…):   0%|          | 0.00/2.71M [00:00<?, ?B/s]
# train/task478_cls_english_music_classifi(…):   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# train/task488_extract_all_alphabetical_e(…):   0%|          | 0.00/3.24M [00:00<?, ?B/s]
# train/task489_mwsc_question_generation_t(…):   0%|          | 0.00/111k [00:00<?, ?B/s]
# train/task490_mwsc_options_generation_tr(…):   0%|          | 0.00/78.6k [00:00<?, ?B/s]
# train/task491_mwsc_answer_generation_tra(…):   0%|          | 0.00/118k [00:00<?, ?B/s]
# train/task492_mwsc_incorrect_answer_gene(…):   0%|          | 0.00/119k [00:00<?, ?B/s]
# train/task493_review_polarity_classifica(…):   0%|          | 0.00/4.42M [00:00<?, ?B/s]
# train/task494_review_polarity_answer_gen(…):   0%|          | 0.00/4.53M [00:00<?, ?B/s]
# train/task495_semeval_headline_classific(…):   0%|          | 0.00/3.76M [00:00<?, ?B/s]
# train/task496_semeval_answer_generation_(…):   0%|          | 0.00/2.87M [00:00<?, ?B/s]
# train/task497_extract_all_numbers_from_l(…):   0%|          | 0.00/3.02M [00:00<?, ?B/s]
# train/task499_extract_and_add_all_number(…):   0%|          | 0.00/2.39M [00:00<?, ?B/s]
# train/task504_count_all_alphabetical_ele(…):   0%|          | 0.00/3.51M [00:00<?, ?B/s]
# train/task505_count_all_numerical_elemen(…):   0%|          | 0.00/3.47M [00:00<?, ?B/s]
# train/task506_position_of_all_alphabetic(…):   0%|          | 0.00/4.21M [00:00<?, ?B/s]
# train/task507_position_of_all_numerical_(…):   0%|          | 0.00/4.14M [00:00<?, ?B/s]
# train/task509_collate_of_all_alphabetica(…):   0%|          | 0.00/5.13M [00:00<?, ?B/s]
# train/task512_twitter_emotion_classifica(…):   0%|          | 0.00/1.43M [00:00<?, ?B/s]
# train/task513_argument_stance_classifica(…):   0%|          | 0.00/90.4k [00:00<?, ?B/s]
# train/task514_argument_consequence_class(…):   0%|          | 0.00/101k [00:00<?, ?B/s]
# train/task515_senteval_odd_word_out_trai(…):   0%|          | 0.00/3.70M [00:00<?, ?B/s]
# train/task516_senteval_conjoints_inversi(…):   0%|          | 0.00/3.79M [00:00<?, ?B/s]
# train/task517_emo_classify_emotion_of_di(…):   0%|          | 0.00/2.55M [00:00<?, ?B/s]
# train/task518_emo_different_dialogue_emo(…):   0%|          | 0.00/3.52M [00:00<?, ?B/s]
# train/task521_trivia_question_classifica(…):   0%|          | 0.00/7.29M [00:00<?, ?B/s]
# train/task522_news_editorial_summary_tra(…):   0%|          | 0.00/2.16M [00:00<?, ?B/s]
# train/task523_find_if_numbers_or_alphabe(…):   0%|          | 0.00/4.43M [00:00<?, ?B/s]
# train/task547_alt_translation_entk_en_tr(…):   0%|          | 0.00/316k [00:00<?, ?B/s]
# train/task550_discofuse_sentence_generat(…):   0%|          | 0.00/316k [00:00<?, ?B/s]
# train/task560_alt_translation_en_entk_tr(…):   0%|          | 0.00/317k [00:00<?, ?B/s]
# train/task563_discofuse_answer_generatio(…):   0%|          | 0.00/553k [00:00<?, ?B/s]
# train/task564_discofuse_classification_t(…):   0%|          | 0.00/921k [00:00<?, ?B/s]
# ...
# train/task905_hate_speech_offensive_clas(…):   0%|          | 0.00/3.31M [00:00<?, ?B/s]
# train/task906_dialogre_identify_names_tr(…):   0%|          | 0.00/351k [00:00<?, ?B/s]
# train/task907_dialogre_identify_relation(…):   0%|          | 0.00/91.2k [00:00<?, ?B/s]
# train/task908_dialogre_identify_familial(…):   0%|          | 0.00/135k [00:00<?, ?B/s]
# train/task909_dialogre_prevalent_speaker(…):   0%|          | 0.00/527k [00:00<?, ?B/s]
# train/task917_coqa_question_generation_t(…):   0%|          | 0.00/1.20M [00:00<?, ?B/s]
# train/task918_coqa_answer_generation_tra(…):   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# train/task919_coqa_incorrect_answer_gene(…):   0%|          | 0.00/223k [00:00<?, ?B/s]
# train/task921_code_x_glue_information_re(…):   0%|          | 0.00/277k [00:00<?, ?B/s]
# train/task922_event2mind_word_generation(…):   0%|          | 0.00/160k [00:00<?, ?B/s]
# train/task923_event2mind_classifier_trai(…):   0%|          | 0.00/1.79M [00:00<?, ?B/s]
# train/task924_event2mind_word_generation(…):   0%|          | 0.00/3.42M [00:00<?, ?B/s]
# train/task925_coached_conv_pref_classifi(…):   0%|          | 0.00/473k [00:00<?, ?B/s]
# train/task926_coached_conv_pref_word_gen(…):   0%|          | 0.00/335k [00:00<?, ?B/s]
# train/task927_yelp_negative_to_positive_(…):   0%|          | 0.00/832k [00:00<?, ?B/s]
# train/task928_yelp_positive_to_negative_(…):   0%|          | 0.00/830k [00:00<?, ?B/s]
# train/task929_products_reviews_classific(…):   0%|          | 0.00/4.35M [00:00<?, ?B/s]
# train/task933_wiki_auto_style_transfer_t(…):   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# train/task934_turk_simplification_train.(…):   0%|          | 0.00/8.69M [00:00<?, ?B/s]
# train/task955_wiki_auto_style_transfer_t(…):   0%|          | 0.00/1.22M [00:00<?, ?B/s]
# train/task956_leetcode_420_strong_passwo(…):   0%|          | 0.00/3.85M [00:00<?, ?B/s]
# train/task963_librispeech_asr_next_word_(…):   0%|          | 0.00/47.6k [00:00<?, ?B/s]
# train/task964_librispeech_asr_text_auto_(…):   0%|          | 0.00/69.9k [00:00<?, ?B/s]
# train/task965_librispeech_asr_missing_wo(…):   0%|          | 0.00/84.7k [00:00<?, ?B/s]
# train/task966_ruletaker_fact_checking_ba(…):   0%|          | 0.00/317k [00:00<?, ?B/s]
# train/task967_ruletaker_incorrect_fact_g(…):   0%|          | 0.00/220k [00:00<?, ?B/s]
# test/task036_qasc_topic_word_to_generate(…):   0%|          | 0.00/4.18M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0/119 [00:00<?, ?files/s]
# test/task033_winogrande_answer_generatio(…):   0%|          | 0.00/3.65M [00:00<?, ?B/s]
# test/task039_qasc_find_overlapping_words(…):   0%|          | 0.00/8.51M [00:00<?, ?B/s]
# test/task1153_bard_analogical_reasoning_(…):   0%|          | 0.00/1.52M [00:00<?, ?B/s]
# test/task050_multirc_answerability_test.(…):   0%|          | 0.00/3.57M [00:00<?, ?B/s]
# test/task034_winogrande_question_modific(…):   0%|          | 0.00/22.7M [00:00<?, ?B/s]
# test/task1155_bard_analogical_reasoning_(…):   0%|          | 0.00/379k [00:00<?, ?B/s]
# test/task020_mctaco_span_based_question_(…):   0%|          | 0.00/241k [00:00<?, ?B/s]
# test/task102_commongen_sentence_generati(…):   0%|          | 0.00/9.79M [00:00<?, ?B/s]
# test/task035_winogrande_question_modific(…):   0%|          | 0.00/12.2M [00:00<?, ?B/s]
# test/task1157_bard_analogical_reasoning_(…):   0%|          | 0.00/666k [00:00<?, ?B/s]
# test/task1154_bard_analogical_reasoning_(…):   0%|          | 0.00/478k [00:00<?, ?B/s]
# test/task1159_bard_analogical_reasoning_(…):   0%|          | 0.00/389k [00:00<?, ?B/s]
# test/task1158_bard_analogical_reasoning_(…):   0%|          | 0.00/233k [00:00<?, ?B/s]
# test/task1156_bard_analogical_reasoning_(…):   0%|          | 0.00/431k [00:00<?, ?B/s]
# test/task1152_bard_analogical_reasoning_(…):   0%|          | 0.00/111k [00:00<?, ?B/s]
# test/task1161_coda19_title_generation_te(…):   0%|          | 0.00/12.9M [00:00<?, ?B/s]
# test/task1195_disflqa_disfluent_to_fluen(…):   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# test/task133_winowhy_reason_plausibility(…):   0%|          | 0.00/4.13M [00:00<?, ?B/s]
# test/task121_zest_text_modification_test(…):   0%|          | 0.00/231k [00:00<?, ?B/s]
# test/task1344_glue_entailment_classifica(…):   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# test/task1342_amazon_us_reviews_title_te(…):   0%|          | 0.00/4.04M [00:00<?, ?B/s]
# test/task1345_glue_qqp_question_parapras(…):   0%|          | 0.00/2.88M [00:00<?, ?B/s]
# test/task1385_anli_r1_entailment_test.js(…):   0%|          | 0.00/858k [00:00<?, ?B/s]
# test/task1356_xlsum_title_generation_tes(…):   0%|          | 0.00/18.9M [00:00<?, ?B/s]
# test/task1358_xlsum_title_generation_tes(…):   0%|          | 0.00/3.45M [00:00<?, ?B/s]
# test/task1386_anli_r2_entailment_test.js(…):   0%|          | 0.00/847k [00:00<?, ?B/s]
# test/task1387_anli_r3_entailment_test.js(…):   0%|          | 0.00/1.01M [00:00<?, ?B/s]
# test/task1388_cb_entailment_test.jsonl:   0%|          | 0.00/238k [00:00<?, ?B/s]
# test/task1390_wscfixed_coreference_test.(…):   0%|          | 0.00/356k [00:00<?, ?B/s]
# test/task1391_winogrande_easy_answer_gen(…):   0%|          | 0.00/2.92M [00:00<?, ?B/s]
# test/task1393_superglue_copa_text_comple(…):   0%|          | 0.00/303k [00:00<?, ?B/s]
# test/task1394_meta_woz_task_classificati(…):   0%|          | 0.00/340k [00:00<?, ?B/s]
# test/task1409_dart_text_generation_test.(…):   0%|          | 0.00/11.3M [00:00<?, ?B/s]
# test/task1407_dart_question_generation_t(…):   0%|          | 0.00/7.13M [00:00<?, ?B/s]
# test/task1439_doqa_cooking_isanswerable_(…):   0%|          | 0.00/4.05M [00:00<?, ?B/s]
# test/task1442_doqa_movies_isanswerable_t(…):   0%|          | 0.00/2.99M [00:00<?, ?B/s]
# test/task1516_imppres_naturallanguageinf(…):   0%|          | 0.00/403k [00:00<?, ?B/s]
# test/task1529_scitail1.1_classification_(…):   0%|          | 0.00/3.85M [00:00<?, ?B/s]
# test/task1531_daily_dialog_type_classifi(…):   0%|          | 0.00/320k [00:00<?, ?B/s]
# test/task1533_daily_dialog_formal_classi(…):   0%|          | 0.00/6.69M [00:00<?, ?B/s]
# test/task1534_daily_dialog_question_clas(…):   0%|          | 0.00/5.88M [00:00<?, ?B/s]
# test/task1540_parsed_pdfs_summarization_(…):   0%|          | 0.00/4.47M [00:00<?, ?B/s]
# test/task1562_zest_text_modification_tes(…):   0%|          | 0.00/182k [00:00<?, ?B/s]
# test/task1557_jfleg_answer_generation_te(…):   0%|          | 0.00/349k [00:00<?, ?B/s]
# test/task1554_scitail_classification_tes(…):   0%|          | 0.00/4.18M [00:00<?, ?B/s]
# test/task1586_scifact_title_generation_t(…):   0%|          | 0.00/9.00M [00:00<?, ?B/s]
# test/task1598_nyc_long_text_generation_t(…):   0%|          | 0.00/3.47M [00:00<?, ?B/s]
# test/task1612_sick_label_classification_(…):   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# test/task1615_sick_tclassify_b_relation_(…):   0%|          | 0.00/1.26M [00:00<?, ?B/s]
# test/task1622_disfl_qa_text_modication_t(…):   0%|          | 0.00/1.01M [00:00<?, ?B/s]
# test/task1624_disfl_qa_question_yesno_cl(…):   0%|          | 0.00/2.26M [00:00<?, ?B/s]
# test/task1631_openpi_answer_generation_t(…):   0%|          | 0.00/1.42M [00:00<?, ?B/s]
# test/task1640_aqa1.0_answerable_unanswer(…):   0%|          | 0.00/3.26M [00:00<?, ?B/s]
# test/task1659_title_generation_test.json(…):   0%|          | 0.00/10.8M [00:00<?, ?B/s]
# test/task1664_winobias_text_generation_t(…):   0%|          | 0.00/291k [00:00<?, ?B/s]
# test/task1728_web_nlg_data_to_text_test.(…):   0%|          | 0.00/11.1M [00:00<?, ?B/s]
# test/task190_snli_classification_test.js(…):   0%|          | 0.00/3.76M [00:00<?, ?B/s]
# test/task199_mnli_classification_test.js(…):   0%|          | 0.00/3.77M [00:00<?, ?B/s]
# test/task200_mnli_entailment_classificat(…):   0%|          | 0.00/3.68M [00:00<?, ?B/s]
# test/task201_mnli_neutral_classification(…):   0%|          | 0.00/6.58M [00:00<?, ?B/s]
# test/task202_mnli_contradiction_classifi(…):   0%|          | 0.00/4.71M [00:00<?, ?B/s]
# test/task219_rocstories_title_answer_gen(…):   0%|          | 0.00/4.57M [00:00<?, ?B/s]
# test/task220_rocstories_title_classifica(…):   0%|          | 0.00/4.55M [00:00<?, ?B/s]
# test/task233_iirc_link_exists_classifica(…):   0%|          | 0.00/12.1M [00:00<?, ?B/s]
# test/task232_iirc_link_number_classifica(…):   0%|          | 0.00/11.6M [00:00<?, ?B/s]
# test/task226_english_language_answer_rel(…):   0%|          | 0.00/728k [00:00<?, ?B/s]
# test/task242_tweetqa_classification_test(…):   0%|          | 0.00/4.00M [00:00<?, ?B/s]
# test/task249_enhanced_wsc_pronoun_disamb(…):   0%|          | 0.00/403k [00:00<?, ?B/s]
# test/task281_points_of_correspondence_te(…):   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# test/task288_gigaword_summarization_test(…):   0%|          | 0.00/931k [00:00<?, ?B/s]
# test/task290_tellmewhy_question_answerab(…):   0%|          | 0.00/2.56M [00:00<?, ?B/s]
# test/task304_numeric_fused_head_resoluti(…):   0%|          | 0.00/12.5M [00:00<?, ?B/s]
# test/task329_gap_classification_test.jso(…):   0%|          | 0.00/4.21M [00:00<?, ?B/s]
# test/task330_gap_answer_generation_test.(…):   0%|          | 0.00/3.09M [00:00<?, ?B/s]
# test/task349_squad2.0_answerable_unanswe(…):   0%|          | 0.00/9.28M [00:00<?, ?B/s]
# test/task362_spolin_yesand_prompt_respon(…):   0%|          | 0.00/6.27M [00:00<?, ?B/s]
# test/task391_causal_relationship_test.js(…):   0%|          | 0.00/1.09M [00:00<?, ?B/s]
# test/task392_inverse_causal_relationship(…):   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# test/task393_plausible_result_generation(…):   0%|          | 0.00/457k [00:00<?, ?B/s]
# test/task401_numeric_fused_head_referenc(…):   0%|          | 0.00/3.55M [00:00<?, ?B/s]
# test/task418_persent_title_generation_te(…):   0%|          | 0.00/8.62M [00:00<?, ?B/s]
# test/task402_grailqa_paraphrase_generati(…):   0%|          | 0.00/31.5M [00:00<?, ?B/s]
# test/task442_com_qa_paraphrase_question_(…):   0%|          | 0.00/2.18M [00:00<?, ?B/s]
# test/task500_scruples_anecdotes_title_ge(…):   0%|          | 0.00/14.8M [00:00<?, ?B/s]
# test/task510_reddit_tifu_title_summariza(…):   0%|          | 0.00/13.2M [00:00<?, ?B/s]
# test/task569_recipe_nlg_text_generation_(…):   0%|          | 0.00/6.95M [00:00<?, ?B/s]
# test/task602_wikitext-103_answer_generat(…):   0%|          | 0.00/163k [00:00<?, ?B/s]
# test/task520_aquamuse_answer_given_in_pa(…):   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# test/task613_politifact_text_generation_(…):   0%|          | 0.00/7.64M [00:00<?, ?B/s]
# test/task614_glucose_cause_event_detecti(…):   0%|          | 0.00/7.51M [00:00<?, ?B/s]
# test/task620_ohsumed_medical_subject_hea(…):   0%|          | 0.00/21.4M [00:00<?, ?B/s]
# test/task619_ohsumed_abstract_title_gene(…):   0%|          | 0.00/1.77M [00:00<?, ?B/s]
# test/task623_ohsumed_yes_no_answer_gener(…):   0%|          | 0.00/628k [00:00<?, ?B/s]
# test/task640_esnli_classification_test.j(…):   0%|          | 0.00/71.0k [00:00<?, ?B/s]
# test/task641_esnli_classification_test.j(…):   0%|          | 0.00/96.1k [00:00<?, ?B/s]
# test/task642_esnli_classification_test.j(…):   0%|          | 0.00/136k [00:00<?, ?B/s]
# test/task645_summarization_test.jsonl:   0%|          | 0.00/794k [00:00<?, ?B/s]
# test/task648_answer_generation_test.json(…):   0%|          | 0.00/104k [00:00<?, ?B/s]
# test/task670_ambigqa_question_generation(…):   0%|          | 0.00/6.87M [00:00<?, ?B/s]
# test/task671_ambigqa_text_generation_tes(…):   0%|          | 0.00/2.82M [00:00<?, ?B/s]
# test/task677_ollie_sentence_answer_gener(…):   0%|          | 0.00/2.31M [00:00<?, ?B/s]
# test/task738_perspectrum_classification_(…):   0%|          | 0.00/3.55M [00:00<?, ?B/s]
# test/task743_eurlex_summarization_test.j(…):   0%|          | 0.00/1.54M [00:00<?, ?B/s]
# test/task760_msr_sqa_long_text_generatio(…):   0%|          | 0.00/114k [00:00<?, ?B/s]
# test/task769_qed_summarization_test.json(…):   0%|          | 0.00/1.03M [00:00<?, ?B/s]
# test/task827_copa_commonsense_reasoning_(…):   0%|          | 0.00/522k [00:00<?, ?B/s]
# test/task828_copa_commonsense_cause_effe(…):   0%|          | 0.00/464k [00:00<?, ?B/s]
# test/task880_schema_guided_dstc8_classif(…):   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# test/task879_schema_guided_dstc8_classif(…):   0%|          | 0.00/902k [00:00<?, ?B/s]
# test/task890_gcwd_classification_test.js(…):   0%|          | 0.00/142k [00:00<?, ?B/s]
# test/task891_gap_coreference_resolution_(…):   0%|          | 0.00/140k [00:00<?, ?B/s]
# test/task893_gap_fill_the_blank_corefere(…):   0%|          | 0.00/86.8k [00:00<?, ?B/s]
# test/task892_gap_reverse_coreference_res(…):   0%|          | 0.00/160k [00:00<?, ?B/s]
# test/task935_defeasible_nli_atomic_class(…):   0%|          | 0.00/6.90M [00:00<?, ?B/s]
# test/task936_defeasible_nli_snli_classif(…):   0%|          | 0.00/7.38M [00:00<?, ?B/s]
# test/task937_defeasible_nli_social_class(…):   0%|          | 0.00/5.88M [00:00<?, ?B/s]
# test/task957_e2e_nlg_text_generation_gen(…):   0%|          | 0.00/1.40M [00:00<?, ?B/s]
# test/task970_sherliic_causal_relationshi(…):   0%|          | 0.00/1.09M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/6164188 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/982285 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# ExpectedMoreSplitsError                   Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dataset = load_dataset(
#       2     "Muennighoff/natural-instructions"
#       3 )
#       5 print(dataset)
#
# File ~/anaconda3/envs/UROP-project/lib/python3.13/site-packages/datasets/load.py:1718, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1715     return builder_instance.as_streaming_dataset(split=split)
#    1717 # Download and prepare data
# -> 1718 builder_instance.download_and_prepare(
#    1719     download_config=download_config,
#    1720     download_mode=download_mode,
#    1721     verification_mode=verification_mode,
#    1722     num_proc=num_proc,
#    1723     storage_options=storage_options,
#    1724 )
#    1726 # Build dataset for splits
#    1727 keep_in_memory = (
#    1728     keep_in_memory if keep_in_memory is not None else is_small_dataset(builder_instance.info.dataset_size)
#    1729 )
#
# File ~/anaconda3/envs/UROP-project/lib/python3.13/site-packages/datasets/builder.py:890, in DatasetBuilder.download_and_prepare(self, output_dir, download_config, download_mode, verification_mode, dl_manager, base_path, file_format, max_shard_size, num_proc, storage_options, **download_and_prepare_kwargs)
#     888 if num_proc is not None:
#     889     prepare_split_kwargs["num_proc"] = num_proc
# --> 890 self._download_and_prepare(
#     891     dl_manager=dl_manager,
#     892     verification_mode=verification_mode,
#     893     **prepare_split_kwargs,
#     894     **download_and_prepare_kwargs,
#     895 )
#     896 # Sync info
#     897 self.info.dataset_size = sum(split.num_bytes for split in self.info.splits.values())
#
# File ~/anaconda3/envs/UROP-project/lib/python3.13/site-packages/datasets/builder.py:957, in DatasetBuilder._download_and_prepare(self, dl_manager, verification_mode, **prepare_split_kwargs)
#     954     dl_manager.manage_extracted_files()
#     956 if verification_mode == VerificationMode.BASIC_CHECKS or verification_mode == VerificationMode.ALL_CHECKS:
# --> 957     verify_splits(self.info.splits, split_dict)
#     959 # Update the info object with the splits.
#     960 self.info.splits = split_dict
#
# File ~/anaconda3/envs/UROP-project/lib/python3.13/site-packages/datasets/utils/info_utils.py:67, in verify_splits(expected_splits, recorded_splits)
#      65     return
#      66 if len(set(expected_splits) - set(recorded_splits)) > 0:
# ---> 67     raise ExpectedMoreSplitsError(str(set(expected_splits) - set(recorded_splits)))
#      68 if len(set(recorded_splits) - set(expected_splits)) > 0:
#      69     raise UnexpectedSplitsError(str(set(recorded_splits) - set(expected_splits)))
#
# ExpectedMoreSplitsError: {'validation'}

# %%
model_name = "Qwen/Qwen3.6-35B-A3B"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
trainDataDF = trainData.to_pandas()

# %%
print(trainDataDF.isnull().sum())
# Out:
# task_name     0
# id            0
# definition    0
# inputs        0
# targets       0
# dtype: int64

# %%
def preprocess(batch):
    text = [f"Defnition:{definitionText}\nInput: {inputText}\nResponse: {responseText}"
            
                for definitionText, inputText, responseText in zip(
                            batch["definition"],
                            batch["inputs"],
                            batch["targets"]
                )
            ]
    return tokenizer(text, truncation=True, padding="max_length", max_length=128)

# %%
dataset = dataset.map(preprocess, batched=True).rename_column("targets", "labels")
dataset.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])
model = AutoModelForCausalLM.from_pretrained(model_name, num_labels=6)
# Out:
# [ERROR] `loss` is part of Qwen3_5MoeCausalLMOutputWithPast.__init__'s signature, but not documented. Make sure to add it to the docstring of the function in /home/jambo/anaconda3/envs/UROP-project/lib/python3.13/site-packages/transformers/models/qwen3_5_moe/modeling_qwen3_5_moe.py.
# [ERROR] `logits` is part of Qwen3_5MoeCausalLMOutputWithPast.__init__'s signature, but not documented. Make sure to add it to the docstring of the function in /home/jambo/anaconda3/envs/UROP-project/lib/python3.13/site-packages/transformers/models/qwen3_5_moe/modeling_qwen3_5_moe.py.
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 26 files:   0%|          | 0/26 [00:00<?, ?it/s]
# /home/jambo/anaconda3/envs/UROP-project/lib/python3.13/site-packages/huggingface_hub/file_download.py:750: UserWarning: Not enough free disk space to download the file. The expected file size is: 1096.46 MB. The target location /home/jambo/.cache/huggingface/hub/models--Qwen--Qwen3.6-35B-A3B/blobs only has 340.96 MB free disk space.
#   warnings.warn(
# /home/jambo/anaconda3/envs/UROP-project/lib/python3.13/site-packages/huggingface_hub/file_download.py:750: UserWarning: Not enough free disk space to download the file. The expected file size is: 3409.97 MB. The target location /home/jambo/.cache/huggingface/hub/models--Qwen--Qwen3.6-35B-A3B/blobs only has 1598.05 MB free disk space.
#   warnings.warn(
# /home/jambo/anaconda3/envs/UROP-project/lib/python3.13/site-packages/huggingface_hub/file_download.py:750: UserWarning: Not enough free disk space to download the file. The expected file size is: 1633.33 MB. The target location /home/jambo/.cache/huggingface/hub/models--Qwen--Qwen3.6-35B-A3B/blobs only has 1598.04 MB free disk space.
#   warnings.warn(
