# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from datasets import load_dataset
from huggingface_hub import hf_hub_download
import json

# Load the dataset
dataset = load_dataset("socratesft/SocSci210") 

# Load a mapping file
mapping_file = hf_hub_download(
    repo_id="socratesft/SocSci210",
    filename="metadata/participant_mapping.json",
    repo_type="dataset"
)

with open(mapping_file, 'r') as f:
    participant_mapping = json.load(f)
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
# Resolving data files:   0%|          | 0/17 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/17 [00:00<?, ?it/s]

# %%
def convertToPandas(dataset,setName):
    return dataset[setName].to_pandas()

# %%
datasetTrainPS = convertToPandas(dataset,"train")
datasetTrainPS.head()

studyIdValues = set()
for studyValue in datasetTrainPS["study_id"]:
    studyIdValues.add(studyValue)
    
print(len(studyIdValues))
# Out:
# 210

# %%
datasetTrainPS["demographic"]
# Out:
# 0          {'age': 34, 'education': 'Post grad study/prof...
# 1          {'age': 34, 'education': 'Post grad study/prof...
# 2          {'age': 67, 'education': 'Bachelor's degree', ...
# 3          {'age': 67, 'education': 'Bachelor's degree', ...
# 4          {'age': 79, 'education': 'Post grad study/prof...
#                                  ...
# 2901385    {'age': 17, 'education': None, 'employment': N...
# 2901386    {'age': 17, 'education': None, 'employment': N...
# 2901387    {'age': 17, 'education': None, 'employment': N...
# 2901388    {'age': 17, 'education': None, 'employment': N...
# 2901389    {'age': 17, 'education': None, 'employment': N...
# Name: demographic, Length: 2901390, dtype: object

# %%
education_dataframe = pd.concat([
    datasetTrainPS[["study_id"]].reset_index(drop=True),
    pd.DataFrame(datasetTrainPS["demographic"].tolist())
], axis=1)

# %%
education_dataframe.head()
# Out:
#   study_id   age                            education  \
# 0    9nphm  34.0  Post grad study/professional degree
# 1    9nphm  34.0  Post grad study/professional degree
# 2    9nphm  67.0                    Bachelor's degree
# 3    9nphm  67.0                    Bachelor's degree
# 4    9nphm  79.0  Post grad study/professional degree
#
#                   employment ethnicity  gender  household_size  \
# 0  Employed as paid employee       NaN  Female             4.0
# 1  Employed as paid employee       NaN  Female             4.0
# 2                    Retired       NaN    Male             2.0
# 3                    Retired       NaN    Male             2.0
# 4                    Retired       NaN    Male             2.0
#
#                                    housing_ownership  \
# 0  Owned or being bought by you or someone in you...
# 1  Owned or being bought by you or someone in you...
# 2  Owned or being bought by you or someone in you...
# 3  Owned or being bought by you or someone in you...
# 4  Owned or being bought by you or someone in you...
#
#                                         housing_type               ideology  \
# 0               A building with 2 or more apartments               Moderate
# 1               A building with 2 or more apartments               Moderate
# 2  A one-family house attached to one or more houses  Somewhat Conservative
# 3  A one-family house attached to one or more houses  Somewhat Conservative
# 4   A one-family house detached from any other house               Moderate
#
#       income     internet_access    location marital_status metro_status  \
# 0     75-99K  Internet Household  New Jersey        Married   Metro Area
# 1     75-99K  Internet Household  New Jersey        Married   Metro Area
# 2  150-175K+  Internet Household        Iowa        Married   Metro Area
# 3  150-175K+  Internet Household        Iowa        Married   Metro Area
# 4     40-49K  Internet Household     Indiana        Married   Metro Area
#
#                       party_id   phone_service
# 0            Moderate Democrat  Cellphone only
# 1            Moderate Democrat  Cellphone only
# 2  Don't Lean/Independent/None  Cellphone only
# 3  Don't Lean/Independent/None  Cellphone only
# 4              Strong Democrat  Cellphone only

# %%
#checking for nan values
print(education_dataframe["education"].isna().sum())
#removing them
education_dataframe = education_dataframe.dropna(
    subset=["education"]
)
# Out:
# 79758

# %%
values = set()
#education_dataframe["education"] = education_dataframe.dropna(subset=["education"], inplace=True)
valueRow = 0
totalRows = 0
for educationValue in education_dataframe["education"]:
    values.add(educationValue)
    if educationValue == "8.0" or educationValue == "14.0":
        print("found at row: ", valueRow)
        totalRows += 1
    valueRow += 1
    
print(totalRows)
# Out:
# found at row:  189103
# found at row:  189104
# found at row:  189105
# found at row:  189106
# found at row:  189107
# found at row:  189108
# found at row:  189109
# found at row:  189110
# found at row:  189111
# found at row:  189112
# found at row:  189200
# found at row:  189201
# found at row:  189202
# found at row:  189203
# found at row:  189204
# found at row:  189205
# found at row:  189206
# found at row:  189207
# found at row:  189208
# found at row:  189209
# found at row:  189260
# found at row:  189261
# found at row:  189262
# found at row:  189263
# found at row:  189264
# found at row:  189265
# found at row:  189266
# found at row:  189267
# found at row:  189268
# found at row:  189269
# found at row:  189366
# found at row:  189367
# found at row:  189368
# found at row:  189369
# found at row:  189370
# found at row:  189371
# found at row:  189372
# found at row:  189373
# found at row:  189374
# found at row:  189375
# found at row:  189722
# found at row:  189723
# found at row:  189724
# found at row:  189725
# found at row:  189726
# found at row:  189727
# found at row:  189728
# found at row:  189729
# found at row:  189730
# found at row:  189731
# found at row:  189812
# found at row:  189813
# found at row:  189814
# found at row:  189815
# found at row:  189816
# found at row:  189817
# found at row:  189818
# found at row:  189819
# found at row:  189820
# found at row:  189821
# found at row:  189960
# found at row:  189961
# found at row:  189962
# found at row:  189963
# found at row:  189964
# found at row:  189965
# found at row:  189966
# found at row:  189967
# found at row:  189968
# found at row:  189969
# found at row:  190070
# found at row:  190071
# found at row:  190072
# found at row:  190073
# found at row:  190074
# found at row:  190075
# found at row:  190076
# found at row:  190077
# found at row:  190078
# found at row:  190079
# found at row:  190484
# found at row:  190485
# found at row:  190486
# found at row:  190487
# found at row:  190488
# found at row:  190489
# found at row:  190490
# found at row:  190491
# found at row:  190492
# found at row:  190493
# found at row:  190731
# found at row:  190732
# found at row:  190733
# found at row:  190734
# found at row:  190735
# found at row:  190736
# found at row:  190737
# found at row:  190738
# found at row:  190739
# found at row:  190740
# found at row:  191306
# found at row:  191307
# found at row:  191308
# found at row:  191309
# found at row:  191310
# found at row:  191311
# found at row:  191312
# found at row:  191313
# found at row:  191314
# found at row:  191315
# found at row:  191434
# found at row:  191435
# found at row:  191436
# found at row:  191437
# found at row:  191438
# found at row:  191439
# found at row:  191440
# found at row:  191441
# found at row:  191442
# found at row:  191443
# found at row:  191444
# found at row:  191445
# found at row:  191446
# found at row:  191447
# found at row:  191448
# found at row:  191449
# found at row:  191450
# found at row:  191451
# found at row:  191452
# found at row:  191453
# found at row:  191632
# found at row:  191633
# found at row:  191634
# found at row:  191635
# found at row:  191636
# found at row:  191637
# found at row:  191638
# found at row:  191639
# found at row:  191650
# found at row:  191651
# found at row:  191652
# found at row:  191653
# found at row:  191654
# found at row:  191655
# found at row:  191656
# found at row:  191657
# found at row:  191658
# found at row:  191659
# found at row:  191728
# found at row:  191729
# found at row:  191730
# found at row:  191731
# found at row:  191732
# found at row:  191733
# found at row:  191734
# found at row:  191735
# found at row:  191736
# found at row:  191737
# found at row:  191964
# found at row:  191965
# found at row:  191966
# found at row:  191967
# found at row:  191968
# found at row:  191969
# found at row:  191970
# found at row:  191971
# found at row:  191972
# found at row:  191973
# found at row:  192203
# found at row:  192204
# found at row:  192205
# found at row:  192206
# found at row:  192207
# found at row:  192208
# found at row:  192209
# found at row:  192210
# found at row:  192211
# found at row:  192212
# found at row:  192413
# found at row:  192414
# found at row:  192415
# found at row:  192416
# found at row:  192417
# found at row:  192418
# found at row:  192419
# found at row:  192420
# found at row:  192421
# found at row:  192422
# found at row:  192451
# found at row:  192452
# found at row:  192453
# found at row:  192454
# found at row:  192455
# found at row:  192456
# found at row:  192457
# found at row:  192458
# found at row:  192771
# found at row:  192772
# found at row:  192773
# found at row:  192774
# found at row:  192775
# found at row:  192776
# found at row:  192777
# found at row:  192778
# found at row:  192779
# found at row:  192780
# found at row:  192838
# found at row:  192839
# found at row:  192840
# found at row:  192841
# found at row:  192842
# found at row:  192843
# found at row:  192844
# found at row:  192845
# found at row:  192846
# found at row:  192847
# found at row:  192867
# found at row:  192868
# found at row:  192869
# found at row:  192870
# found at row:  192871
# found at row:  192872
# found at row:  192873
# found at row:  192874
# found at row:  192875
# found at row:  192876
# found at row:  192964
# found at row:  192965
# found at row:  192966
# found at row:  192967
# found at row:  192968
# found at row:  192969
# found at row:  192970
# found at row:  192971
# found at row:  192972
# found at row:  192973
# found at row:  193062
# found at row:  193063
# found at row:  193064
# found at row:  193065
# found at row:  193066
# found at row:  193067
# found at row:  193068
# found at row:  193069
# found at row:  193070
# found at row:  193071
# found at row:  193121
# found at row:  193122
# found at row:  193123
# found at row:  193124
# found at row:  193125
# found at row:  193126
# found at row:  193127
# found at row:  193128
# found at row:  193129
# found at row:  193130
# found at row:  193229
# found at row:  193230
# found at row:  193231
# found at row:  193232
# found at row:  193233
# found at row:  193234
# found at row:  193235
# found at row:  193236
# found at row:  193237
# found at row:  193238
# found at row:  193384
# found at row:  193385
# found at row:  193386
# found at row:  193387
# found at row:  193388
# found at row:  193389
# found at row:  193390
# found at row:  193391
# found at row:  193392
# found at row:  193393
# found at row:  193444
# found at row:  193445
# found at row:  193555
# found at row:  193556
# found at row:  193557
# found at row:  193558
# found at row:  193559
# found at row:  193560
# found at row:  193561
# found at row:  193562
# found at row:  193563
# found at row:  193564
# found at row:  193790
# found at row:  193791
# found at row:  193792
# found at row:  193793
# found at row:  193794
# found at row:  193795
# found at row:  193796
# found at row:  193797
# found at row:  193798
# found at row:  193799
# found at row:  193880
# found at row:  193881
# found at row:  193882
# found at row:  193883
# found at row:  193884
# found at row:  193885
# found at row:  193886
# found at row:  193887
# found at row:  193888
# found at row:  193889
# found at row:  194089
# found at row:  194090
# found at row:  194091
# found at row:  194092
# found at row:  194093
# found at row:  194094
# found at row:  194095
# found at row:  194096
# found at row:  194097
# found at row:  194098
# found at row:  194104
# found at row:  194105
# found at row:  194106
# found at row:  194107
# found at row:  194108
# found at row:  194109
# found at row:  194110
# found at row:  194111
# found at row:  194112
# found at row:  194113
# found at row:  194143
# found at row:  194144
# found at row:  194145
# found at row:  194146
# found at row:  194147
# found at row:  194148
# found at row:  194149
# found at row:  194150
# found at row:  194151
# found at row:  194321
# found at row:  194322
# found at row:  194323
# found at row:  194324
# found at row:  194325
# found at row:  194326
# found at row:  194327
# found at row:  194328
# found at row:  194329
# found at row:  194330
# found at row:  194379
# found at row:  194380
# found at row:  194381
# found at row:  194382
# found at row:  194383
# found at row:  194384
# found at row:  194385
# found at row:  194386
# found at row:  194387
# found at row:  194603
# found at row:  194604
# found at row:  194605
# found at row:  194606
# found at row:  194607
# found at row:  194608
# found at row:  194609
# found at row:  194610
# found at row:  194611
# found at row:  194612
# found at row:  194623
# found at row:  194624
# found at row:  194625
# found at row:  194626
# found at row:  194627
# found at row:  194628
# found at row:  194629
# found at row:  194630
# found at row:  194631
# found at row:  194632
# found at row:  194782
# found at row:  194783
# found at row:  194784
# found at row:  194785
# found at row:  194786
# found at row:  194787
# found at row:  194788
# found at row:  194789
# found at row:  194790
# found at row:  194791
# found at row:  195116
# found at row:  195117
# found at row:  195118
# found at row:  195119
# found at row:  195120
# found at row:  195121
# found at row:  195122
# found at row:  195123
# found at row:  195124
# found at row:  195125
# found at row:  195205
# found at row:  195206
# found at row:  195207
# found at row:  195208
# found at row:  195209
# found at row:  195210
# found at row:  195211
# found at row:  195212
# found at row:  195213
# found at row:  195214
# found at row:  195215
# found at row:  195216
# found at row:  195217
# found at row:  195218
# found at row:  195219
# found at row:  195220
# found at row:  195221
# found at row:  195222
# found at row:  195223
# found at row:  195224
# found at row:  195383
# found at row:  195384
# found at row:  195385
# found at row:  195386
# found at row:  195387
# found at row:  195388
# found at row:  195389
# found at row:  195390
# found at row:  195391
# found at row:  195392
# found at row:  195520
# found at row:  195521
# found at row:  195522
# found at row:  195523
# found at row:  195524
# found at row:  195525
# found at row:  195526
# found at row:  195527
# found at row:  195528
# found at row:  195529
# found at row:  195669
# found at row:  195670
# found at row:  195671
# found at row:  195672
# found at row:  195673
# found at row:  195674
# found at row:  195675
# found at row:  195676
# found at row:  195677
# found at row:  195678
# found at row:  195719
# found at row:  195720
# found at row:  195721
# found at row:  195722
# found at row:  195723
# found at row:  195724
# found at row:  195725
# found at row:  195726
# found at row:  195727
# found at row:  195728
# found at row:  195966
# found at row:  195967
# found at row:  195968
# found at row:  195969
# found at row:  195970
# found at row:  195971
# found at row:  195972
# found at row:  195973
# found at row:  195974
# found at row:  196075
# found at row:  196076
# found at row:  196077
# found at row:  196078
# found at row:  196079
# found at row:  196080
# found at row:  196081
# found at row:  196082
# found at row:  196083
# found at row:  196084
# found at row:  196340
# found at row:  196341
# found at row:  196342
# found at row:  196343
# found at row:  196344
# found at row:  196345
# found at row:  196346
# found at row:  196347
# found at row:  196348
# found at row:  196349
# found at row:  196615
# found at row:  196616
# found at row:  196617
# found at row:  196618
# found at row:  196619
# found at row:  196620
# found at row:  196621
# found at row:  196622
# found at row:  196623
# found at row:  196624
# found at row:  196654
# found at row:  196655
# found at row:  196656
# found at row:  196657
# found at row:  196658
# found at row:  196659
# found at row:  196660
# found at row:  196661
# found at row:  196662
# found at row:  196663
# found at row:  197180
# found at row:  197181
# found at row:  197182
# found at row:  197183
# found at row:  197184
# found at row:  197185
# found at row:  197186
# found at row:  197187
# found at row:  197188
# found at row:  197189
# found at row:  197522
# found at row:  197523
# found at row:  197524
# found at row:  197525
# found at row:  197526
# found at row:  197527
# found at row:  197528
# found at row:  197529
# found at row:  197530
# found at row:  197531
# found at row:  197840
# found at row:  197841
# found at row:  197842
# found at row:  197843
# found at row:  197844
# found at row:  197845
# found at row:  197846
# found at row:  197847
# found at row:  197848
# found at row:  197849
# found at row:  197850
# found at row:  197851
# found at row:  197852
# found at row:  197853
# found at row:  197854
# found at row:  197855
# found at row:  197856
# found at row:  198072
# found at row:  198073
# found at row:  198074
# found at row:  198075
# found at row:  198076
# found at row:  198077
# found at row:  198078
# found at row:  198079
# found at row:  198080
# found at row:  198081
# found at row:  198082
# found at row:  198083
# found at row:  198084
# found at row:  198085
# found at row:  198086
# found at row:  198087
# found at row:  198088
# found at row:  198089
# found at row:  198090
# found at row:  198091
# found at row:  198666
# found at row:  198667
# found at row:  198668
# found at row:  198669
# found at row:  198670
# found at row:  198671
# found at row:  198672
# found at row:  198673
# found at row:  198674
# found at row:  198675
# found at row:  198785
# found at row:  198786
# found at row:  198787
# found at row:  198788
# found at row:  198789
# found at row:  198790
# found at row:  198791
# found at row:  198792
# found at row:  198793
# found at row:  198794
# found at row:  199372
# found at row:  199373
# found at row:  199374
# found at row:  199375
# found at row:  199376
# found at row:  199377
# found at row:  199378
# found at row:  199379
# found at row:  199380
# found at row:  199381
# found at row:  199555
# found at row:  199556
# found at row:  199557
# found at row:  199558
# found at row:  199559
# found at row:  199560
# found at row:  199561
# found at row:  199562
# found at row:  199563
# found at row:  199564
# found at row:  199815
# found at row:  199816
# found at row:  199817
# found at row:  199818
# found at row:  199819
# found at row:  199820
# found at row:  199821
# found at row:  199822
# found at row:  199823
# found at row:  199824
# found at row:  199930
# found at row:  199931
# found at row:  199932
# found at row:  199933
# found at row:  199934
# found at row:  199935
# found at row:  199936
# found at row:  199937
# found at row:  199948
# found at row:  199949
# found at row:  199950
# found at row:  199951
# found at row:  199952
# found at row:  199953
# found at row:  199954
# found at row:  199955
# found at row:  199956
# found at row:  199957
# 630

# %%
print(values)
# Out:
# {'14.0', "Bachelor's degree", 'Less than high school', '8.0', 'High school graduate or equivalent', 'Some high school (no diploma)', 'Post grad study/professional degree', 'Vocational/tech school/some college/associates'}

# %%
education_dataframe = education_dataframe[education_dataframe['education'] != "8.0"]
education_dataframe = education_dataframe[education_dataframe['education'] != "14.0"]

# %%
education_dataframe.head()
# Out:
#   study_id   age                            education  \
# 0    9nphm  34.0  Post grad study/professional degree
# 1    9nphm  34.0  Post grad study/professional degree
# 2    9nphm  67.0                    Bachelor's degree
# 3    9nphm  67.0                    Bachelor's degree
# 4    9nphm  79.0  Post grad study/professional degree
#
#                   employment ethnicity  gender  household_size  \
# 0  Employed as paid employee       NaN  Female             4.0
# 1  Employed as paid employee       NaN  Female             4.0
# 2                    Retired       NaN    Male             2.0
# 3                    Retired       NaN    Male             2.0
# 4                    Retired       NaN    Male             2.0
#
#                                    housing_ownership  \
# 0  Owned or being bought by you or someone in you...
# 1  Owned or being bought by you or someone in you...
# 2  Owned or being bought by you or someone in you...
# 3  Owned or being bought by you or someone in you...
# 4  Owned or being bought by you or someone in you...
#
#                                         housing_type               ideology  \
# 0               A building with 2 or more apartments               Moderate
# 1               A building with 2 or more apartments               Moderate
# 2  A one-family house attached to one or more houses  Somewhat Conservative
# 3  A one-family house attached to one or more houses  Somewhat Conservative
# 4   A one-family house detached from any other house               Moderate
#
#       income     internet_access    location marital_status metro_status  \
# 0     75-99K  Internet Household  New Jersey        Married   Metro Area
# 1     75-99K  Internet Household  New Jersey        Married   Metro Area
# 2  150-175K+  Internet Household        Iowa        Married   Metro Area
# 3  150-175K+  Internet Household        Iowa        Married   Metro Area
# 4     40-49K  Internet Household     Indiana        Married   Metro Area
#
#                       party_id   phone_service
# 0            Moderate Democrat  Cellphone only
# 1            Moderate Democrat  Cellphone only
# 2  Don't Lean/Independent/None  Cellphone only
# 3  Don't Lean/Independent/None  Cellphone only
# 4              Strong Democrat  Cellphone only

# %%
studyIdValues = set()
for studyValue in education_dataframe["study_id"]:
    studyIdValues.add(studyValue)

# %%
len(studyIdValues)
# Out:
# 201

# %%
educationalMapValue = {"Bachelor's degree":4, 
                       "Less than high school": 0, 
                       "High school graduate or equivalent":2, 
                       "Some high school (no diploma)": 1, 
                       "Post grad study/professional degree":5, 
                       "Vocational/tech school/some college/associates":3
}

education_dataframe["education_num_representation"] = (
    education_dataframe["education"].map(educationalMapValue)
)

# %%
education_dataframe.head()
# Out:
#   study_id   age                            education  \
# 0    9nphm  34.0  Post grad study/professional degree
# 1    9nphm  34.0  Post grad study/professional degree
# 2    9nphm  67.0                    Bachelor's degree
# 3    9nphm  67.0                    Bachelor's degree
# 4    9nphm  79.0  Post grad study/professional degree
#
#                   employment ethnicity  gender  household_size  \
# 0  Employed as paid employee       NaN  Female             4.0
# 1  Employed as paid employee       NaN  Female             4.0
# 2                    Retired       NaN    Male             2.0
# 3                    Retired       NaN    Male             2.0
# 4                    Retired       NaN    Male             2.0
#
#                                    housing_ownership  \
# 0  Owned or being bought by you or someone in you...
# 1  Owned or being bought by you or someone in you...
# 2  Owned or being bought by you or someone in you...
# 3  Owned or being bought by you or someone in you...
# 4  Owned or being bought by you or someone in you...
#
#                                         housing_type               ideology  \
# 0               A building with 2 or more apartments               Moderate
# 1               A building with 2 or more apartments               Moderate
# 2  A one-family house attached to one or more houses  Somewhat Conservative
# 3  A one-family house attached to one or more houses  Somewhat Conservative
# 4   A one-family house detached from any other house               Moderate
#
#       income     internet_access    location marital_status metro_status  \
# 0     75-99K  Internet Household  New Jersey        Married   Metro Area
# 1     75-99K  Internet Household  New Jersey        Married   Metro Area
# 2  150-175K+  Internet Household        Iowa        Married   Metro Area
# 3  150-175K+  Internet Household        Iowa        Married   Metro Area
# 4     40-49K  Internet Household     Indiana        Married   Metro Area
#
#                       party_id   phone_service  education_num_representation
# 0            Moderate Democrat  Cellphone only                             5
# 1            Moderate Democrat  Cellphone only                             5
# 2  Don't Lean/Independent/None  Cellphone only                             4
# 3  Don't Lean/Independent/None  Cellphone only                             4
# 4              Strong Democrat  Cellphone only                             5

# %%
cols = 4
rows = math.ceil(len(education_dataframe) / cols)

fig, axes = plt.subplots(
    rows,
    cols,
    figsize=(20, rows * 6)
)

for i, study_id in enumerate(studyIdValues):

    study_dataframe = datasetTrainPS[
        datasetTrainPS["study_id"] == study_id
    ]

    education_counts = (
        education_dataframe["education_num_representation"]
        .value_counts()
    )

    education_counts.plot.bar(
        ax=axes[i]
    )

    axes[i].set_title(study_id)
    print("Plotted: ", i, " graphs")

# %%
plt.show()
